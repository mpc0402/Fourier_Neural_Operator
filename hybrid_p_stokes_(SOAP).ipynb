# %% [markdown]
# #Import

# %%
#Install to use SOAP optimizer
# !pip install pytorch-optimizer
# Out:
# Requirement already satisfied: pytorch-optimizer in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy>1.24.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-optimizer) (2.0.2)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.12/dist-packages (from pytorch-optimizer) (2.10.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10->pytorch-optimizer) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.10->pytorch-optimizer) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10->pytorch-optimizer) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10->pytorch-optimizer) (3.0.3)

# %%
#Import base library
import numpy as np
import pytorch_optimizer as optim

import torch
import torch.nn as nn
from torch.autograd import Variable
# import random

#..and check a device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda:0

# %% [markdown]
# #Build Network

# %%
#Try some activation functions: tanh, Swish(SiLU)
from math import tanh

#Structure of Swish function
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return  x* self.sigmoid(x)

#Activation function in this experiment
activation = nn.SiLU()
activation_ = nn.SiLU()

#Coefficient for solution PDE
k=1

# %%
#Width of NN
M = 100


T = True
F = False

#Architecture of NN: 4 layers with M width, 3 input values and 1 output value
#NN for approximating u1 and u2
class Net_2D(nn.Module):
    def __init__(self):
        super(Net_2D, self).__init__()
        torch.manual_seed(1234) # Fix Initial_Parameter
        self.hidden_layer1 = nn.Linear(3,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer2 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer3 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer4 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        #self.hidden_layer5 = nn.Linear(M,M, bias = T)
        #torch.manual_seed(1234)
        self.output_layer = nn.Linear(M,1, bias = T)

    def forward(self, x,y,p):
        inputs = torch.cat([x,y,p],axis=1)
        layer1_out = activation(self.hidden_layer1(inputs))
        layer2_out = activation(self.hidden_layer2(layer1_out))
        layer3_out = activation(self.hidden_layer3(layer2_out))
        layer4_out = activation(self.hidden_layer4(layer3_out))
        #layer5_out = activation(self.hidden_layer5(layer4_out))
        output = self.output_layer(layer4_out)

        return output

#NN for approximating P
class Net_2D_f(nn.Module):
    def __init__(self):
        super(Net_2D_f, self).__init__()
        torch.manual_seed(1234) # Fix Initial_Parameter
        self.hidden_layer1 = nn.Linear(3,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer2 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer3 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer4 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        #self.hidden_layer5 = nn.Linear(M,M, bias = T)
        #torch.manual_seed(1234)
        self.output_layer = nn.Linear(M,1, bias = T)

    def forward(self, x,y,p):
        inputs = torch.cat([x,y,p],axis=1)
        layer1_out = activation_(self.hidden_layer1(inputs))
        layer2_out = activation_(self.hidden_layer2(layer1_out))
        layer3_out = activation_(self.hidden_layer3(layer2_out))
        layer4_out = activation_(self.hidden_layer4(layer3_out))
        #layer5_out = activation(self.hidden_layer5(layer4_out))
        output = self.output_layer(layer4_out)

        return output

# %%
mse_cost_function = torch.nn.MSELoss() #MSE Function can be shared

#NN to approximate u1
net_2d_1 = Net_2D()
net_2d_1 = net_2d_1.to(device)

#NN to approximate u2
net_2d_2 = Net_2D()
net_2d_2 = net_2d_2.to(device)

#NN to approximate P
net_2d_P = Net_2D_f()
net_2d_P = net_2d_P.to(device)

#Optimizer: SOAP, Learning rate: 0.001
optimizer1_h = optim.SOAP(net_2d_1.parameters(),lr=0.001)
optimizer2_h = optim.SOAP(net_2d_2.parameters(),lr=0.001)
optimizerP_h = optim.SOAP(net_2d_P.parameters(),lr=0.001)

# %% [markdown]
# #set PDE,residual

# %%
def f3(x,y,p,x_bdy,y_bdy, f1,f2, net1, net2, netP):
    ##------------------------ Network output -------------------------------
    P = netP(x,y,p)
    w = net1(x,y,p)
    v = net2(x,y,p)

    w_bdy = net1(x_bdy,y_bdy,p)
    v_bdy = net2(x_bdy,y_bdy,p)
    ##--------------------Differentiation------------------------------------

    P_x = torch.autograd.grad(P.sum(), x, create_graph=True)[0]
    P_y = torch.autograd.grad(P.sum(), y, create_graph=True)[0]

    w_x = torch.autograd.grad(w.sum(), x, create_graph=True)[0]
    w_y = torch.autograd.grad(w.sum(), y, create_graph=True)[0]

    v_x = torch.autograd.grad(v.sum(), x, create_graph=True)[0]
    v_y = torch.autograd.grad(v.sum(), y, create_graph=True)[0]

    AbsDu = (w_x**2 + w_y**2 + v_x**2 + v_y**2)**((p-2)/2)

    div11 = torch.autograd.grad((AbsDu*w_x).sum(), x, create_graph=True)[0]
    div12 = torch.autograd.grad((AbsDu*w_y).sum(), y, create_graph=True)[0]
    div21 = torch.autograd.grad((AbsDu*v_x).sum(), x, create_graph=True)[0]
    div22 = torch.autograd.grad((AbsDu*v_y).sum(), y, create_graph=True)[0]

    ##-----------------------Calculate Variational----------------------------
    Integral = (P.mean())**2

    Bdy = (w_bdy**2 + v_bdy**2).mean()

    Var = ((1/p)*(w_x**2 + w_y**2 + v_x**2 + v_y**2)**(p/2) - (f1*w + f2*v)).mean()

    Div = ((w_x + v_y)**2).mean()

    gradP = ((P_x - f1 - div11 - div12)**2).mean() + ((P_y - f2 - div21 - div22)**2).mean()

    return gradP + Var + Integral + 1000*Bdy + 1000*Div

# %% [markdown]
# #Set data point

# %%
#Function to check if a point is inside the circle
def is_inside(x, y):

    return x**2 + y**2 < 1


#Generate random points inside the domain
def generate_random_points(n_points=1000):
    points = []
    while len(points) < n_points:
        x = np.random.uniform(-1, 1)
        y = np.random.uniform(-1, 1)
        if is_inside(x, y):
            points.append((x, y))
    return np.array(points)

#Example usage
random_points = generate_random_points(2000)

x_coords_ = random_points[:, 0].reshape(-1, 1)
y_coords_ = random_points[:, 1].reshape(-1, 1)
p_coords_ = (2*np.random.rand(len(x_coords_)) + 2).reshape(-1, 1)   #2 < p < 4

pt_x_collocation = Variable(torch.from_numpy(x_coords_).float(), requires_grad=True).to(device)
pt_y_collocation = Variable(torch.from_numpy(y_coords_).float(), requires_grad=True).to(device)
pt_p_collocation = Variable(torch.from_numpy(p_coords_).float(), requires_grad=True).to(device)

#-----------------------------set F-------------------------------------------------

pt_x = Variable(torch.from_numpy(x_coords_).float(), requires_grad=False).to(device)
pt_y = Variable(torch.from_numpy(y_coords_).float(), requires_grad=False).to(device)
pt_p = Variable(torch.from_numpy(p_coords_).float(), requires_grad=False).to(device)

pt_Q = k**(pt_p - 2)*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-2)/2)
pt_Q_x = k**(pt_p - 2)*((pt_p-2)/2*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-4)/2) * (16*(pt_x)*(pt_y**2) - 4*pt_x*(1 - pt_x**2 - 3*(pt_y**2)) + 12*pt_x*(-1 + 3*(pt_x**2) + pt_y**2)))
pt_Q_y = k**(pt_p - 2)*((pt_p-2)/2*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-4)/2) * (16*(pt_x**2)*(pt_y) - 12*pt_y*(1 - pt_x**2 - 3*(pt_y**2)) + 4*pt_y*(-1 + 3*(pt_x**2) + pt_y**2)))

F1 = -(pt_Q_x*(-2*pt_x*pt_y) + pt_Q*(-2*pt_y) + pt_Q_y*(1 - pt_x**2 - 3*pt_y**2) + pt_Q*(-6*pt_y)) + 3
F2 = -(pt_Q_x*(-1 + 3*pt_x**2 + pt_y**2) + pt_Q*(6*pt_x) + pt_Q_y*(2*pt_x*pt_y) + pt_Q*(2*pt_x)) + 3

# %%
#Boundary points

theta1 = np.linspace(0, 2*np.pi, 2000)

x_coords1 = np.cos(theta1).reshape(-1, 1)
y_coords1 = np.sin(theta1).reshape(-1, 1)

bdy_x = Variable(torch.from_numpy(x_coords1).float(), requires_grad=True).to(device)
bdy_y = Variable(torch.from_numpy(y_coords1).float(), requires_grad=True).to(device)

# %%
#Solution u1 function
sol_u = k*(pt_y*(1 - pt_x**2 - pt_y**2))

#Solution u2 function
sol_v = k*(-pt_x*(1 - pt_x**2 - pt_y**2))

#Solution P function
sol_P = 3*(pt_x + pt_y)

# %% [markdown]
# #Train

# %%
error_list1 = []
error_list2 = []
error_list3 = []
loss_list1 = []

previous_validation_loss = 99999999.0
epoch = 0

while epoch < 30000:
    optimizer1_h.zero_grad()
    optimizer2_h.zero_grad()
    optimizerP_h.zero_grad()

##------------------------------------Compute Loss-----------------------------------------##

    loss = 1*f3(pt_x_collocation, pt_y_collocation, pt_p_collocation, bdy_x, bdy_y, F1, F2, net_2d_1, net_2d_2, net_2d_P)


##------------------------------------Optimize Loss-----------------------------------------##

    loss.backward()
    optimizer1_h.step()
    optimizer2_h.step()
    optimizerP_h.step()

    epoch += 1

##----------------------------Adaptive learningrate-----------------------------##
    if (epoch) % 50 == 1:
            print("-----------------------------------------------------------------------------")
            print("Epoch:",epoch)

            gap_1 = torch.sqrt(((sol_u - net_2d_1(pt_x, pt_y, pt_p))**2).mean()/((sol_u)**2).mean())
            gap_2 = torch.sqrt(((sol_v - net_2d_2(pt_x, pt_y, pt_p))**2).mean()/((sol_v)**2).mean())
            gap_3 = torch.sqrt(((sol_P - net_2d_P(pt_x, pt_y, pt_p))**2).mean()/((sol_P)**2).mean())

            print('error of u1:',gap_1)
            print('error of u2:',gap_2)
            print('error of P:',gap_3)

            print("Loss :", (loss).item())
            error_list1.append(gap_1.item())
            error_list2.append(gap_2.item())
            error_list3.append(gap_3.item())
            loss_list1.append(loss.item())
# Out:
# -----------------------------------------------------------------------------
# Epoch: 1
# error of u1: tensor(1.0049, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.0074, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9998, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 244.1774444580078
# -----------------------------------------------------------------------------
# Epoch: 51
# error of u1: tensor(0.9923, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9911, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9908, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 243.71702575683594
# -----------------------------------------------------------------------------
# Epoch: 101
# error of u1: tensor(0.9913, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9900, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9733, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 243.08631896972656
# -----------------------------------------------------------------------------
# Epoch: 151
# error of u1: tensor(0.9900, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9886, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9388, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 241.8524169921875
# -----------------------------------------------------------------------------
# Epoch: 201
# error of u1: tensor(0.9842, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9829, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.8725, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 239.5547637939453
# -----------------------------------------------------------------------------
# Epoch: 251
# error of u1: tensor(0.9720, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9676, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.7552, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 235.75335693359375
# -----------------------------------------------------------------------------
# Epoch: 301
# error of u1: tensor(0.9463, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9384, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5712, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 230.08755493164062
# -----------------------------------------------------------------------------
# Epoch: 351
# error of u1: tensor(0.9085, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.8821, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.3326, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 221.67510986328125
# -----------------------------------------------------------------------------
# Epoch: 401
# error of u1: tensor(0.9013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.7783, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.2254, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 203.36598205566406
# -----------------------------------------------------------------------------
# Epoch: 451
# error of u1: tensor(0.9567, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.5993, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5025, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 150.3874053955078
# -----------------------------------------------------------------------------
# Epoch: 501
# error of u1: tensor(0.3356, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2506, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5266, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 52.49431228637695
# -----------------------------------------------------------------------------
# Epoch: 551
# error of u1: tensor(0.1404, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1413, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1521, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 3.694918632507324
# -----------------------------------------------------------------------------
# Epoch: 601
# error of u1: tensor(0.0430, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0399, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0501, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.9014312028884888
# -----------------------------------------------------------------------------
# Epoch: 651
# error of u1: tensor(0.0276, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0234, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0651, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.1977592706680298
# -----------------------------------------------------------------------------
# Epoch: 701
# error of u1: tensor(0.0259, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0221, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0769, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2504549026489258
# -----------------------------------------------------------------------------
# Epoch: 751
# error of u1: tensor(0.0243, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0177, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0786, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2617753744125366
# -----------------------------------------------------------------------------
# Epoch: 801
# error of u1: tensor(0.0199, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0220, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0779, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2673261165618896
# -----------------------------------------------------------------------------
# Epoch: 851
# error of u1: tensor(0.0232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0818, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2730156183242798
# -----------------------------------------------------------------------------
# Epoch: 901
# error of u1: tensor(0.0214, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0164, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0827, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2722076177597046
# -----------------------------------------------------------------------------
# Epoch: 951
# error of u1: tensor(0.0252, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0217, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0823, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2762340307235718
# -----------------------------------------------------------------------------
# Epoch: 1001
# error of u1: tensor(0.0249, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0201, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0819, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2755134105682373
# -----------------------------------------------------------------------------
# Epoch: 1051
# error of u1: tensor(0.0227, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0276, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0821, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2702182531356812
# -----------------------------------------------------------------------------
# Epoch: 1101
# error of u1: tensor(0.0266, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0169, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0820, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2759894132614136
# -----------------------------------------------------------------------------
# Epoch: 1151
# error of u1: tensor(0.0175, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0221, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0818, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2746984958648682
# -----------------------------------------------------------------------------
# Epoch: 1201
# error of u1: tensor(0.0257, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0221, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0818, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2747256755828857
# -----------------------------------------------------------------------------
# Epoch: 1251
# error of u1: tensor(0.0192, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0204, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0817, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2727633714675903
# -----------------------------------------------------------------------------
# Epoch: 1301
# error of u1: tensor(0.0253, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0231, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0828, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.276932954788208
# -----------------------------------------------------------------------------
# Epoch: 1351
# error of u1: tensor(0.0237, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0210, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0833, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2755063772201538
# -----------------------------------------------------------------------------
# Epoch: 1401
# error of u1: tensor(0.0213, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0202, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0834, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2739208936691284
# -----------------------------------------------------------------------------
# Epoch: 1451
# error of u1: tensor(0.0246, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0219, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0850, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.275914192199707
# -----------------------------------------------------------------------------
# Epoch: 1501
# error of u1: tensor(0.0178, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0236, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0853, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2734973430633545
# -----------------------------------------------------------------------------
# Epoch: 1551
# error of u1: tensor(0.0244, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0183, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0862, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2727394104003906
# -----------------------------------------------------------------------------
# Epoch: 1601
# error of u1: tensor(0.0204, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0258, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0870, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2775081396102905
# -----------------------------------------------------------------------------
# Epoch: 1651
# error of u1: tensor(0.0207, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0209, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0869, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2745379209518433
# -----------------------------------------------------------------------------
# Epoch: 1701
# error of u1: tensor(0.0237, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0234, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0875, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2703498601913452
# -----------------------------------------------------------------------------
# Epoch: 1751
# error of u1: tensor(0.0215, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0186, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0874, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2759565114974976
# -----------------------------------------------------------------------------
# Epoch: 1801
# error of u1: tensor(0.0202, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0233, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0879, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.277104377746582
# -----------------------------------------------------------------------------
# Epoch: 1851
# error of u1: tensor(0.0265, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0229, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0888, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2762371301651
# -----------------------------------------------------------------------------
# Epoch: 1901
# error of u1: tensor(0.0178, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0237, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0888, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2768527269363403
# -----------------------------------------------------------------------------
# Epoch: 1951
# error of u1: tensor(0.0188, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0182, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0897, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2758702039718628
# -----------------------------------------------------------------------------
# Epoch: 2001
# error of u1: tensor(0.0215, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0271, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0901, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2769899368286133
# -----------------------------------------------------------------------------
# Epoch: 2051
# error of u1: tensor(0.0193, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0234, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0905, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2781316041946411
# -----------------------------------------------------------------------------
# Epoch: 2101
# error of u1: tensor(0.0227, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0246, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0913, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2763581275939941
# -----------------------------------------------------------------------------
# Epoch: 2151
# error of u1: tensor(0.0191, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0222, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0918, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.27836012840271
# -----------------------------------------------------------------------------
# Epoch: 2201
# error of u1: tensor(0.0232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0256, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0919, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2771310806274414
# -----------------------------------------------------------------------------
# Epoch: 2251
# error of u1: tensor(0.0230, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0214, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0925, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2790182828903198
# -----------------------------------------------------------------------------
# Epoch: 2301
# error of u1: tensor(0.0239, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0927, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2767431735992432
# -----------------------------------------------------------------------------
# Epoch: 2351
# error of u1: tensor(0.0205, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0223, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0936, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.273392677307129
# -----------------------------------------------------------------------------
# Epoch: 2401
# error of u1: tensor(0.0193, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0224, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0932, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2744219303131104
# -----------------------------------------------------------------------------
# Epoch: 2451
# error of u1: tensor(0.0237, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0225, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0939, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2773438692092896
# -----------------------------------------------------------------------------
# Epoch: 2501
# error of u1: tensor(0.0215, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0243, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0942, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2739211320877075
# -----------------------------------------------------------------------------
# Epoch: 2551
# error of u1: tensor(0.0217, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0222, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0948, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2760593891143799
# -----------------------------------------------------------------------------
# Epoch: 2601
# error of u1: tensor(0.0223, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0244, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0952, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2756456136703491
# -----------------------------------------------------------------------------
# Epoch: 2651
# error of u1: tensor(0.0213, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0223, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0945, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2767572402954102
# -----------------------------------------------------------------------------
# Epoch: 2701
# error of u1: tensor(0.0232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0218, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0951, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2786303758621216
# -----------------------------------------------------------------------------
# Epoch: 2751
# error of u1: tensor(0.0240, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0192, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0948, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.278420329093933
# -----------------------------------------------------------------------------
# Epoch: 2801
# error of u1: tensor(0.0240, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0263, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0947, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2764973640441895
# -----------------------------------------------------------------------------
# Epoch: 2851
# error of u1: tensor(0.0238, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0204, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0939, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2794948816299438
# -----------------------------------------------------------------------------
# Epoch: 2901
# error of u1: tensor(0.0217, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0239, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0937, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2712064981460571
# -----------------------------------------------------------------------------
# Epoch: 2951
# error of u1: tensor(0.0266, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0256, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0944, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2784603834152222
# -----------------------------------------------------------------------------
# Epoch: 3001
# error of u1: tensor(0.0188, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0245, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0945, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2793216705322266
# -----------------------------------------------------------------------------
# Epoch: 3051
# error of u1: tensor(0.0232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0263, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0942, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2780871391296387
# -----------------------------------------------------------------------------
# Epoch: 3101
# error of u1: tensor(0.0245, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0294, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0937, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2780464887619019
# -----------------------------------------------------------------------------
# Epoch: 3151
# error of u1: tensor(0.0280, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0209, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0940, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2715920209884644
# -----------------------------------------------------------------------------
# Epoch: 3201
# error of u1: tensor(0.0236, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0235, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0937, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2779620885849
# -----------------------------------------------------------------------------
# Epoch: 3251
# error of u1: tensor(0.0210, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0245, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0929, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2780805826187134
# -----------------------------------------------------------------------------
# Epoch: 3301
# error of u1: tensor(0.0213, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0277, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0935, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2782045602798462
# -----------------------------------------------------------------------------
# Epoch: 3351
# error of u1: tensor(0.0196, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0259, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0940, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2764387130737305
# -----------------------------------------------------------------------------
# Epoch: 3401
# error of u1: tensor(0.0201, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0234, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0937, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.278913974761963
# -----------------------------------------------------------------------------
# Epoch: 3451
# error of u1: tensor(0.0202, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0202, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0942, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.278455138206482
# -----------------------------------------------------------------------------
# Epoch: 3501
# error of u1: tensor(0.0242, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0229, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0945, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2780473232269287
# -----------------------------------------------------------------------------
# Epoch: 3551
# error of u1: tensor(0.0226, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0247, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0946, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2787697315216064
# -----------------------------------------------------------------------------
# Epoch: 3601
# error of u1: tensor(0.0266, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0242, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0949, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2785491943359375
# -----------------------------------------------------------------------------
# Epoch: 3651
# error of u1: tensor(0.0201, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0217, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0952, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2786900997161865
# -----------------------------------------------------------------------------
# Epoch: 3701
# error of u1: tensor(0.0229, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0261, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0958, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2795063257217407
# -----------------------------------------------------------------------------
# Epoch: 3751
# error of u1: tensor(0.0213, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0273, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0955, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2765523195266724
# -----------------------------------------------------------------------------
# Epoch: 3801
# error of u1: tensor(0.0263, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0253, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0962, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2781915664672852
# -----------------------------------------------------------------------------
# Epoch: 3851
# error of u1: tensor(0.0203, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0212, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0964, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2783550024032593
# -----------------------------------------------------------------------------
# Epoch: 3901
# error of u1: tensor(0.0202, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0241, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0970, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2765533924102783
# -----------------------------------------------------------------------------
# Epoch: 3951
# error of u1: tensor(0.0225, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0241, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0961, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2793350219726562
# -----------------------------------------------------------------------------
# Epoch: 4001
# error of u1: tensor(0.0221, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0238, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0971, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2794537544250488
# -----------------------------------------------------------------------------
# Epoch: 4051
# error of u1: tensor(0.0262, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0226, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0967, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2786760330200195
# -----------------------------------------------------------------------------
# Epoch: 4101
# error of u1: tensor(0.0250, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0219, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0970, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2795885801315308
# -----------------------------------------------------------------------------
# Epoch: 4151
# error of u1: tensor(0.0221, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0233, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0971, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2791191339492798
# -----------------------------------------------------------------------------
# Epoch: 4201
# error of u1: tensor(0.0222, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0224, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0965, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2795366048812866
# -----------------------------------------------------------------------------
# Epoch: 4251
# error of u1: tensor(0.0222, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0247, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0965, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.279587745666504
# -----------------------------------------------------------------------------
# Epoch: 4301
# error of u1: tensor(0.0240, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0240, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0965, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2795251607894897
# -----------------------------------------------------------------------------
# Epoch: 4351
# error of u1: tensor(0.0190, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0298, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0965, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.273603081703186
# -----------------------------------------------------------------------------
# Epoch: 4401
# error of u1: tensor(0.0238, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0220, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0977, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2803590297698975
# -----------------------------------------------------------------------------
# Epoch: 4451
# error of u1: tensor(0.0237, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0208, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0979, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280868411064148
# -----------------------------------------------------------------------------
# Epoch: 4501
# error of u1: tensor(0.0241, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0270, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0985, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280388355255127
# -----------------------------------------------------------------------------
# Epoch: 4551
# error of u1: tensor(0.0232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0244, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0987, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2798051834106445
# -----------------------------------------------------------------------------
# Epoch: 4601
# error of u1: tensor(0.0230, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0262, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0991, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2806591987609863
# -----------------------------------------------------------------------------
# Epoch: 4651
# error of u1: tensor(0.0239, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0998, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280662178993225
# -----------------------------------------------------------------------------
# Epoch: 4701
# error of u1: tensor(0.0211, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0267, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1008, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2793595790863037
# -----------------------------------------------------------------------------
# Epoch: 4751
# error of u1: tensor(0.0251, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0228, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1012, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2808994054794312
# -----------------------------------------------------------------------------
# Epoch: 4801
# error of u1: tensor(0.0216, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0224, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1014, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2780364751815796
# -----------------------------------------------------------------------------
# Epoch: 4851
# error of u1: tensor(0.0240, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0245, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1016, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280603289604187
# -----------------------------------------------------------------------------
# Epoch: 4901
# error of u1: tensor(0.0277, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0268, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1021, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.279821753501892
# -----------------------------------------------------------------------------
# Epoch: 4951
# error of u1: tensor(0.0227, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0220, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1034, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280438780784607
# -----------------------------------------------------------------------------
# Epoch: 5001
# error of u1: tensor(0.0212, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0219, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1042, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2805818319320679
# -----------------------------------------------------------------------------
# Epoch: 5051
# error of u1: tensor(0.0244, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0267, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1052, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2783195972442627
# -----------------------------------------------------------------------------
# Epoch: 5101
# error of u1: tensor(0.0253, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0257, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1050, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280724048614502
# -----------------------------------------------------------------------------
# Epoch: 5151
# error of u1: tensor(0.0229, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0286, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1057, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2804332971572876
# -----------------------------------------------------------------------------
# Epoch: 5201
# error of u1: tensor(0.0224, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0249, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1064, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2804487943649292
# -----------------------------------------------------------------------------
# Epoch: 5251
# error of u1: tensor(0.0210, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0231, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1081, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280491590499878
# -----------------------------------------------------------------------------
# Epoch: 5301
# error of u1: tensor(0.0239, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0259, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1083, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2810089588165283
# -----------------------------------------------------------------------------
# Epoch: 5351
# error of u1: tensor(0.0242, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0238, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1088, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2809057235717773
# -----------------------------------------------------------------------------
# Epoch: 5401
# error of u1: tensor(0.0262, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0275, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1083, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2815191745758057
# -----------------------------------------------------------------------------
# Epoch: 5451
# error of u1: tensor(0.0238, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0296, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1088, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2810850143432617
# -----------------------------------------------------------------------------
# Epoch: 5501
# error of u1: tensor(0.0210, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0279, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1105, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.281772255897522
# -----------------------------------------------------------------------------
# Epoch: 5551
# error of u1: tensor(0.0231, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0262, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1101, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2815405130386353
# -----------------------------------------------------------------------------
# Epoch: 5601
# error of u1: tensor(0.0251, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0246, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1102, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2814750671386719
# -----------------------------------------------------------------------------
# Epoch: 5651
# error of u1: tensor(0.0220, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0250, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1105, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2822500467300415
# -----------------------------------------------------------------------------
# Epoch: 5701
# error of u1: tensor(0.0247, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0305, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1108, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.281191110610962
# -----------------------------------------------------------------------------
# Epoch: 5751
# error of u1: tensor(0.0252, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0256, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1106, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280469298362732
# -----------------------------------------------------------------------------
# Epoch: 5801
# error of u1: tensor(0.0231, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0272, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1105, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2815862894058228
# -----------------------------------------------------------------------------
# Epoch: 5851
# error of u1: tensor(0.0238, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0250, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1103, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2814347743988037
# -----------------------------------------------------------------------------
# Epoch: 5901
# error of u1: tensor(0.0295, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0261, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1111, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2817462682724
# -----------------------------------------------------------------------------
# Epoch: 5951
# error of u1: tensor(0.0255, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0250, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1113, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.283043622970581
# -----------------------------------------------------------------------------
# Epoch: 6001
# error of u1: tensor(0.0235, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0249, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1115, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2820476293563843
# -----------------------------------------------------------------------------
# Epoch: 6051
# error of u1: tensor(0.0237, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0258, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1126, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2806494235992432
# -----------------------------------------------------------------------------
# Epoch: 6101
# error of u1: tensor(0.0239, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0266, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1127, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.282710075378418
# -----------------------------------------------------------------------------
# Epoch: 6151
# error of u1: tensor(0.0260, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0283, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1129, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2788242101669312
# -----------------------------------------------------------------------------
# Epoch: 6201
# error of u1: tensor(0.0248, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0269, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1131, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2824811935424805
# -----------------------------------------------------------------------------
# Epoch: 6251
# error of u1: tensor(0.0228, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0251, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1139, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2809991836547852
# -----------------------------------------------------------------------------
# Epoch: 6301
# error of u1: tensor(0.0244, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0288, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1141, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2825874090194702
# -----------------------------------------------------------------------------
# Epoch: 6351
# error of u1: tensor(0.0238, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0265, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1149, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.282613754272461
# -----------------------------------------------------------------------------
# Epoch: 6401
# error of u1: tensor(0.0254, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0256, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1158, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2819428443908691
# -----------------------------------------------------------------------------
# Epoch: 6451
# error of u1: tensor(0.0262, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0244, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1163, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2815054655075073
# -----------------------------------------------------------------------------
# Epoch: 6501
# error of u1: tensor(0.0261, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0289, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1170, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.283358097076416
# -----------------------------------------------------------------------------
# Epoch: 6551
# error of u1: tensor(0.0247, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0287, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1173, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2830491065979004
# -----------------------------------------------------------------------------
# Epoch: 6601
# error of u1: tensor(0.0256, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0327, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1181, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2831488847732544
# -----------------------------------------------------------------------------
# Epoch: 6651
# error of u1: tensor(0.0247, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0261, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1179, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.280012607574463
# -----------------------------------------------------------------------------
# Epoch: 6701
# error of u1: tensor(0.0259, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0302, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1188, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.283955454826355
# -----------------------------------------------------------------------------
# Epoch: 6751
# error of u1: tensor(0.0263, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0291, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1190, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2837284803390503
# -----------------------------------------------------------------------------
# Epoch: 6801
# error of u1: tensor(0.0259, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0296, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1192, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2836344242095947
# -----------------------------------------------------------------------------
# Epoch: 6851
# error of u1: tensor(0.0243, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0280, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1193, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2834572792053223
# -----------------------------------------------------------------------------
# Epoch: 6901
# error of u1: tensor(0.0278, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0296, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1195, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2826753854751587
# -----------------------------------------------------------------------------
# Epoch: 6951
# error of u1: tensor(0.0283, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0299, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1200, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2846004962921143
# -----------------------------------------------------------------------------
# Epoch: 7001
# error of u1: tensor(0.0259, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0312, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1196, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2843204736709595
# -----------------------------------------------------------------------------
# Epoch: 7051
# error of u1: tensor(0.0274, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0311, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1197, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2838932275772095
# -----------------------------------------------------------------------------
# Epoch: 7101
# error of u1: tensor(0.0275, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0347, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1194, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.285333275794983
# -----------------------------------------------------------------------------
# Epoch: 7151
# error of u1: tensor(0.0268, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0335, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1190, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2844221591949463
# -----------------------------------------------------------------------------
# Epoch: 7201
# error of u1: tensor(0.0298, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0325, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1193, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2853609323501587
# -----------------------------------------------------------------------------
# Epoch: 7251
# error of u1: tensor(0.0277, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0350, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1188, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2838736772537231
# -----------------------------------------------------------------------------
# Epoch: 7301
# error of u1: tensor(0.0309, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0342, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.1184, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.284700632095337
# -----------------------------------------------------------------------------
# Epoch: 7351
# ...
# Epoch: 27551
# error of u1: tensor(0.9024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.5886, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5515, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6747808456420898
# -----------------------------------------------------------------------------
# Epoch: 27601
# error of u1: tensor(0.9049, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.5941, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5540, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6909970045089722
# -----------------------------------------------------------------------------
# Epoch: 27651
# error of u1: tensor(0.9064, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6102, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5543, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6284235715866089
# -----------------------------------------------------------------------------
# Epoch: 27701
# error of u1: tensor(0.9118, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6069, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5564, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7334712743759155
# -----------------------------------------------------------------------------
# Epoch: 27751
# error of u1: tensor(0.9150, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6074, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5556, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7218601703643799
# -----------------------------------------------------------------------------
# Epoch: 27801
# error of u1: tensor(0.9172, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6122, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5578, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6816977262496948
# -----------------------------------------------------------------------------
# Epoch: 27851
# error of u1: tensor(0.9209, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6164, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5583, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.76146399974823
# -----------------------------------------------------------------------------
# Epoch: 27901
# error of u1: tensor(0.9232, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6254, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5592, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7451242208480835
# -----------------------------------------------------------------------------
# Epoch: 27951
# error of u1: tensor(0.9262, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6247, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5597, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7404606342315674
# -----------------------------------------------------------------------------
# Epoch: 28001
# error of u1: tensor(0.9313, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6266, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5616, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7365434169769287
# -----------------------------------------------------------------------------
# Epoch: 28051
# error of u1: tensor(0.9341, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6319, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5616, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6981217861175537
# -----------------------------------------------------------------------------
# Epoch: 28101
# error of u1: tensor(0.9366, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6428, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5610, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7710566520690918
# -----------------------------------------------------------------------------
# Epoch: 28151
# error of u1: tensor(0.9389, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6438, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5627, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7325170040130615
# -----------------------------------------------------------------------------
# Epoch: 28201
# error of u1: tensor(0.9440, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6519, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5638, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7362123727798462
# -----------------------------------------------------------------------------
# Epoch: 28251
# error of u1: tensor(0.9473, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6575, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5655, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7439802885055542
# -----------------------------------------------------------------------------
# Epoch: 28301
# error of u1: tensor(0.9488, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6637, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5656, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7288689613342285
# -----------------------------------------------------------------------------
# Epoch: 28351
# error of u1: tensor(0.9493, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6608, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5666, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6944701671600342
# -----------------------------------------------------------------------------
# Epoch: 28401
# error of u1: tensor(0.9443, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6678, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5671, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7207162380218506
# -----------------------------------------------------------------------------
# Epoch: 28451
# error of u1: tensor(0.9572, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6648, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5673, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.717689037322998
# -----------------------------------------------------------------------------
# Epoch: 28501
# error of u1: tensor(0.9608, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6774, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5701, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7210643291473389
# -----------------------------------------------------------------------------
# Epoch: 28551
# error of u1: tensor(0.9623, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6768, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5698, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7822664976119995
# -----------------------------------------------------------------------------
# Epoch: 28601
# error of u1: tensor(0.9607, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6875, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5698, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6790727376937866
# -----------------------------------------------------------------------------
# Epoch: 28651
# error of u1: tensor(0.9604, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6906, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5700, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7079055309295654
# -----------------------------------------------------------------------------
# Epoch: 28701
# error of u1: tensor(0.9690, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.6890, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5720, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.753319501876831
# -----------------------------------------------------------------------------
# Epoch: 28751
# error of u1: tensor(0.9743, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7000, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5740, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.780897855758667
# -----------------------------------------------------------------------------
# Epoch: 28801
# error of u1: tensor(0.9767, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7056, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5762, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7158344984054565
# -----------------------------------------------------------------------------
# Epoch: 28851
# error of u1: tensor(0.9735, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7112, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5755, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.746013879776001
# -----------------------------------------------------------------------------
# Epoch: 28901
# error of u1: tensor(0.9837, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7140, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5761, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.775679111480713
# -----------------------------------------------------------------------------
# Epoch: 28951
# error of u1: tensor(0.9835, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7163, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5775, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6983965635299683
# -----------------------------------------------------------------------------
# Epoch: 29001
# error of u1: tensor(0.9867, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7187, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5785, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7519736289978027
# -----------------------------------------------------------------------------
# Epoch: 29051
# error of u1: tensor(0.9866, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7233, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5791, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7706507444381714
# -----------------------------------------------------------------------------
# Epoch: 29101
# error of u1: tensor(0.9897, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7235, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5783, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7795006036758423
# -----------------------------------------------------------------------------
# Epoch: 29151
# error of u1: tensor(0.9918, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7338, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5811, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7149440050125122
# -----------------------------------------------------------------------------
# Epoch: 29201
# error of u1: tensor(0.9938, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7335, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5821, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.723479151725769
# -----------------------------------------------------------------------------
# Epoch: 29251
# error of u1: tensor(0.9965, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7410, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5802, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7864712476730347
# -----------------------------------------------------------------------------
# Epoch: 29301
# error of u1: tensor(0.9960, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7387, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5848, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7576701641082764
# -----------------------------------------------------------------------------
# Epoch: 29351
# error of u1: tensor(1.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7459, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5821, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7223719358444214
# -----------------------------------------------------------------------------
# Epoch: 29401
# error of u1: tensor(1.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7577, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5853, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7626103162765503
# -----------------------------------------------------------------------------
# Epoch: 29451
# error of u1: tensor(1.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7544, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5863, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7615300416946411
# -----------------------------------------------------------------------------
# Epoch: 29501
# error of u1: tensor(1.0091, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7524, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5857, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7618980407714844
# -----------------------------------------------------------------------------
# Epoch: 29551
# error of u1: tensor(1.0139, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7624, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5878, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7751975059509277
# -----------------------------------------------------------------------------
# Epoch: 29601
# error of u1: tensor(1.0111, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7653, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5882, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7888051271438599
# -----------------------------------------------------------------------------
# Epoch: 29651
# error of u1: tensor(1.0176, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7646, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5873, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7507718801498413
# -----------------------------------------------------------------------------
# Epoch: 29701
# error of u1: tensor(1.0156, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7667, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5899, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7532240152359009
# -----------------------------------------------------------------------------
# Epoch: 29751
# error of u1: tensor(1.0174, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7796, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5922, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.8025485277175903
# -----------------------------------------------------------------------------
# Epoch: 29801
# error of u1: tensor(1.0203, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7759, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5906, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7891165018081665
# -----------------------------------------------------------------------------
# Epoch: 29851
# error of u1: tensor(1.0255, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7845, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5921, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.775070309638977
# -----------------------------------------------------------------------------
# Epoch: 29901
# error of u1: tensor(1.0307, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7867, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5947, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.7621748447418213
# -----------------------------------------------------------------------------
# Epoch: 29951
# error of u1: tensor(1.0295, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.7891, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.5932, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.8066396713256836

# %% [markdown]
# Error Curve

# %%
import matplotlib.pyplot as plt

plt.plot(error_list1, label='Error of u1')
plt.plot(error_list2, label='Error of u2')
plt.plot(error_list3, label='Error of P')

plt.title('Hybrid method for p-Stokes Equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Error')
plt.yscale('log')

plt.legend()

plt.show()

# %% [markdown]
# Loss Curve

# %%
import matplotlib.pyplot as plt

plt.plot(loss_list1, label='Hybrid Loss')

#plt.title('Hybrid method for p-Stokes Equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Loss')
#plt.yscale('log')

plt.legend()

plt.show()

# %% [markdown]
# #Plotting Prediction

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import torch
from torch.autograd import Variable

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

#Radius of circle domain
r=1

#Generate points
x_collocation = []
y_collocation = []
p_collocation = []

theta = np.linspace(0, 2*np.pi, 120)
x = np.cos(theta)
y = np.sin(theta)

X, Y = np.meshgrid(x, y)

pt_x = Variable(torch.from_numpy(X).float(), requires_grad=False).to(device)
pt_y = Variable(torch.from_numpy(Y).float(), requires_grad=False).to(device)

pt_x = pt_x.reshape(-1,1)
pt_y = pt_y.reshape(-1,1)
pt_p = 2*torch.ones_like(pt_x) + 2   #2 < p < 4

#Approximated functions
Predict1 = net_2d_1(pt_x, pt_y, pt_p)
Predict2 = net_2d_2(pt_x, pt_y, pt_p)
Predict3 = net_2d_P(pt_x, pt_y, pt_p)

#True solution functions
Truesol1 = k*pt_y * (r**2 - pt_x**2 - pt_y**2)
Truesol2 = -k*pt_x * (r**2 - pt_x**2 - pt_y**2)
Truesol3 = 3*(pt_x + pt_y)

Predict1 = Predict1.data.cpu().numpy()
Predict2 = Predict2.data.cpu().numpy()
Predict3 = Predict3.data.cpu().numpy()
Truesol1 = Truesol1.data.cpu().numpy()
Truesol2 = Truesol2.data.cpu().numpy()
Truesol3 = Truesol3.data.cpu().numpy()

PR_u1 = Predict1.reshape(X.shape)
PR_u2 = Predict2.reshape(X.shape)
PR_P = Predict3.reshape(X.shape)
Truesol1 = Truesol1.reshape(X.shape)
Truesol2 = Truesol2.reshape(X.shape)
Truesol3 = Truesol3.reshape(X.shape)

#Masking points
mask = (X**2 + Y**2 > r**2)
PR_u1[mask] = 0
PR_u2[mask] = 0
PR_P[mask] = 0
Truesol1[mask] = 0
Truesol2[mask] = 0
Truesol3[mask] = 0

#3D surface plot
#surf = ax.plot_surface(X, Y, PR_u2, cmap=cm.coolwarm, linewidth=0, antialiased=False)
#surf = ax.plot_surface(X, Y, Truesol3, cmap=cm.coolwarm, linewidth=0, antialiased=False)
surf = ax.plot_surface(X, Y, (Truesol3 - PR_P), cmap=cm.coolwarm, linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=4)
#plt.title('Solution - Prediction for p=3 (P)')

# z축 범위 및 눈금 설정
#ax.set_zlim(0, 1)  # z축의 값 범위를 설정
#ax.set_zticks(np.arange(0, 1, 0.1))  # z축 눈금을 -0.15부터 0.15까지 0.05 간격으로 설정

plt.show()

# %% [markdown]
# # PINN for p-Stokes Equation

# %%
M = 100

T = True
F = False

class Net_2D(nn.Module):
    def __init__(self):
        super(Net_2D, self).__init__()
        torch.manual_seed(1234) # Fix Initial_Parameter
        self.hidden_layer1 = nn.Linear(3,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer2 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer3 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer4 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer5 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.output_layer = nn.Linear(M,1, bias = T)

    def forward(self, x,y,p):
        inputs = torch.cat([x,y,p],axis=1)
        layer1_out = activation(self.hidden_layer1(inputs))
        layer2_out = activation(self.hidden_layer2(layer1_out))
        layer3_out = activation(self.hidden_layer3(layer2_out))
        layer4_out = activation(self.hidden_layer4(layer3_out))
        #layer5_out = activation(self.hidden_layer5(layer4_out))
        output = self.output_layer(layer4_out)

        return output

class Net_2D_f(nn.Module):
    def __init__(self):
        super(Net_2D_f, self).__init__()
        torch.manual_seed(1234) # Fix Initial_Parameter
        self.hidden_layer1 = nn.Linear(3,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer2 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer3 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer4 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer5 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.output_layer = nn.Linear(M,1, bias = T)

    def forward(self, x,y,p):
        inputs = torch.cat([x,y,p],axis=1)
        layer1_out = activation_(self.hidden_layer1(inputs))
        layer2_out = activation_(self.hidden_layer2(layer1_out))
        layer3_out = activation_(self.hidden_layer3(layer2_out))
        layer4_out = activation_(self.hidden_layer4(layer3_out))
        #layer5_out = activation(self.hidden_layer5(layer4_out))
        output = self.output_layer(layer4_out)

        return output

# %%
mse_cost_function = torch.nn.MSELoss() #MSE Function can be shared

net_pinn_1 = Net_2D()
net_pinn_1 = net_pinn_1.to(device)

net_pinn_2 = Net_2D()
net_pinn_2 = net_pinn_2.to(device)

net_pinn_P = Net_2D_f()
net_pinn_P = net_pinn_P.to(device)

optimizer1_p = optim.SOAP(net_pinn_1.parameters(),lr=0.001)
optimizer2_p = optim.SOAP(net_pinn_2.parameters(),lr=0.001)
optimizerP_p = optim.SOAP(net_pinn_P.parameters(),lr=0.001)

# %%
def f3(x,y,p,x_bdy,y_bdy, f1,f2, net1, net2, netP):
    ##------------------------ Network output -------------------------------
    P = netP(x,y,p)
    w = net1(x,y,p)
    v = net2(x,y,p)

    w_bdy = net1(x_bdy,y_bdy,p)
    v_bdy = net2(x_bdy,y_bdy,p)
    ##--------------------Differentiation--------------------------

    P_x = torch.autograd.grad(P.sum(), x, create_graph=True)[0]
    P_y = torch.autograd.grad(P.sum(), y, create_graph=True)[0]

    w_x = torch.autograd.grad(w.sum(), x, create_graph=True)[0]
    w_y = torch.autograd.grad(w.sum(), y, create_graph=True)[0]

    v_x = torch.autograd.grad(v.sum(), x, create_graph=True)[0]
    v_y = torch.autograd.grad(v.sum(), y, create_graph=True)[0]

    AbsDu = (w_x**2 + w_y**2 + v_x**2 + v_y**2)**((p-2)/2)

    div11 = torch.autograd.grad((AbsDu*w_x).sum(), x, create_graph=True)[0]
    div12 = torch.autograd.grad((AbsDu*w_y).sum(), y, create_graph=True)[0]
    div21 = torch.autograd.grad((AbsDu*v_x).sum(), x, create_graph=True)[0]
    div22 = torch.autograd.grad((AbsDu*v_y).sum(), y, create_graph=True)[0]

    ##-----------------------Calculate Variational----------------------------
    Integral = (P.mean())**2

    Bdy = (w_bdy**2 + v_bdy**2).mean()

    Div = ((w_x + v_y)**2).mean()
    #__
    gradP = ((P_x - f1 - div11 - div12)**2).mean() + ((P_y - f2 - div21 - div22)**2).mean()

    return gradP + Integral + 1000*Bdy + 1000*Div

# %%
#Function to check if a point is inside the circle
def is_inside(x, y):

    return x**2 + y**2 < 1


#Generate random points inside the domain
def generate_random_points(n_points=1000):
    points = []
    while len(points) < n_points:
        x = np.random.uniform(-1, 1)
        y = np.random.uniform(-1, 1)
        if is_inside(x, y):
            points.append((x, y))
    return np.array(points)

#Example usage
random_points = generate_random_points(2000)

x_coords_ = random_points[:, 0].reshape(-1, 1)
y_coords_ = random_points[:, 1].reshape(-1, 1)
p_coords_ = (2*np.random.rand(len(x_coords_)) + 2).reshape(-1, 1)   #2 < p < 4

pt_x_collocation = Variable(torch.from_numpy(x_coords_).float(), requires_grad=True).to(device)
pt_y_collocation = Variable(torch.from_numpy(y_coords_).float(), requires_grad=True).to(device)
pt_p_collocation = Variable(torch.from_numpy(p_coords_).float(), requires_grad=True).to(device)

#-----------------------------set F-------------------------------------------------

pt_x = Variable(torch.from_numpy(x_coords_).float(), requires_grad=False).to(device)
pt_y = Variable(torch.from_numpy(y_coords_).float(), requires_grad=False).to(device)
pt_p = Variable(torch.from_numpy(p_coords_).float(), requires_grad=False).to(device)

pt_Q = k**(pt_p - 2)*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-2)/2)
pt_Q_x = k**(pt_p - 2)*((pt_p-2)/2*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-4)/2) * (16*(pt_x)*(pt_y**2) - 4*pt_x*(1 - pt_x**2 - 3*(pt_y**2)) + 12*pt_x*(-1 + 3*(pt_x**2) + pt_y**2)))
pt_Q_y = k**(pt_p - 2)*((pt_p-2)/2*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-4)/2) * (16*(pt_x**2)*(pt_y) - 12*pt_y*(1 - pt_x**2 - 3*(pt_y**2)) + 4*pt_y*(-1 + 3*(pt_x**2) + pt_y**2)))

F1 = -(pt_Q_x*(-2*pt_x*pt_y) + pt_Q*(-2*pt_y) + pt_Q_y*(1 - pt_x**2 - 3*pt_y**2) + pt_Q*(-6*pt_y)) + 3
F2 = -(pt_Q_x*(-1 + 3*pt_x**2 + pt_y**2) + pt_Q*(6*pt_x) + pt_Q_y*(2*pt_x*pt_y) + pt_Q*(2*pt_x)) + 3

# %%
#Boundary points

theta1 = np.linspace(0, 2*np.pi, 2000)

x_coords1 = np.cos(theta1).reshape(-1, 1)
y_coords1 = np.sin(theta1).reshape(-1, 1)

bdy_x = Variable(torch.from_numpy(x_coords1).float(), requires_grad=True).to(device)
bdy_y = Variable(torch.from_numpy(y_coords1).float(), requires_grad=True).to(device)

# %%
#Solution u1 function
sol_u = k*(pt_y*(1 - pt_x**2 - pt_y**2))

#Solution u2 function
sol_v = k*(-pt_x*(1 - pt_x**2 - pt_y**2))

#Solution P function
sol_P = 3*(pt_x + pt_y)

# %%
error_pinn_list1 = []
error_pinn_list2 = []
error_pinn_list3 = []
loss_list2 = []

previous_validation_loss = 99999999.0
epoch = 0

while epoch < 30000:
    optimizer1_p.zero_grad()
    optimizer2_p.zero_grad()
    optimizerP_p.zero_grad()

##------------------------------------Compute Loss-----------------------------------------##

    loss = 1*f3(pt_x_collocation, pt_y_collocation, pt_p_collocation, bdy_x, bdy_y, F1,F2, net_pinn_1,net_pinn_2,net_pinn_P)

##------------------------------------Optimize Loss-----------------------------------------##

    loss.backward()
    optimizer1_p.step()
    optimizer2_p.step()
    optimizerP_p.step()

    epoch += 1

##----------------------------Adaptive learningrate-----------------------------##

    if (epoch) % 50 == 1:
        print("-----------------------------------------------------------------------------")
        print("Epoch:",epoch)

        gap1 = torch.sqrt((((sol_u - net_pinn_1(pt_x, pt_y, pt_p))**2).mean())/((sol_u)**2).mean())
        gap2 = torch.sqrt((((sol_v - net_pinn_2(pt_x, pt_y, pt_p))**2).mean())/((sol_v)**2).mean())
        gap3 = torch.sqrt((((sol_P - net_pinn_P(pt_x, pt_y, pt_p))**2).mean())/((sol_P)**2).mean())

        print('error of u1:',gap1)
        print('error of u2:',gap2)
        print('error of P:',gap3)

        print("Loss :", (loss).item())
        error_pinn_list1.append(gap1.item())
        error_pinn_list2.append(gap2.item())
        error_pinn_list3.append(gap3.item())
        loss_list2.append(loss.item())
# Out:
# -----------------------------------------------------------------------------
# Epoch: 1
# error of u1: tensor(1.0051, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.0087, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9996, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 228.1387481689453
# -----------------------------------------------------------------------------
# Epoch: 51
# error of u1: tensor(1.0006, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.0007, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9911, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 227.6690216064453
# -----------------------------------------------------------------------------
# Epoch: 101
# error of u1: tensor(0.9998, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9996, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9748, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 227.0164031982422
# -----------------------------------------------------------------------------
# Epoch: 151
# error of u1: tensor(0.9972, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9953, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9429, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 225.73252868652344
# -----------------------------------------------------------------------------
# Epoch: 201
# error of u1: tensor(0.9888, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9830, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.8798, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 223.33055114746094
# -----------------------------------------------------------------------------
# Epoch: 251
# error of u1: tensor(0.9720, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9588, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.7716, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 219.09324645996094
# -----------------------------------------------------------------------------
# Epoch: 301
# error of u1: tensor(0.9417, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9300, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.6082, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 211.78271484375
# -----------------------------------------------------------------------------
# Epoch: 351
# error of u1: tensor(0.8787, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9258, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.4082, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 195.86370849609375
# -----------------------------------------------------------------------------
# Epoch: 401
# error of u1: tensor(0.7531, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.8531, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.4039, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 156.1156463623047
# -----------------------------------------------------------------------------
# Epoch: 451
# error of u1: tensor(0.4267, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3885, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.4763, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 71.87574005126953
# -----------------------------------------------------------------------------
# Epoch: 501
# error of u1: tensor(0.1688, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1262, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.2014, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 8.107800483703613
# -----------------------------------------------------------------------------
# Epoch: 551
# error of u1: tensor(0.0479, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0365, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0899, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.48506098985671997
# -----------------------------------------------------------------------------
# Epoch: 601
# error of u1: tensor(0.0201, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0150, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0790, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.12224411219358444
# -----------------------------------------------------------------------------
# Epoch: 651
# error of u1: tensor(0.0090, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0080, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0704, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.03443514183163643
# -----------------------------------------------------------------------------
# Epoch: 701
# error of u1: tensor(0.0062, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0066, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0700, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.01415651012212038
# -----------------------------------------------------------------------------
# Epoch: 751
# error of u1: tensor(0.0055, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0062, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0711, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.007951180450618267
# -----------------------------------------------------------------------------
# Epoch: 801
# error of u1: tensor(0.0044, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0060, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0678, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.011314972303807735
# -----------------------------------------------------------------------------
# Epoch: 851
# error of u1: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0667, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.009692395105957985
# -----------------------------------------------------------------------------
# Epoch: 901
# error of u1: tensor(0.0056, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0033, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0648, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0033812858164310455
# -----------------------------------------------------------------------------
# Epoch: 951
# error of u1: tensor(0.0031, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0637, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.004847769159823656
# -----------------------------------------------------------------------------
# Epoch: 1001
# error of u1: tensor(0.0035, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0606, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.003573568305000663
# -----------------------------------------------------------------------------
# Epoch: 1051
# error of u1: tensor(0.0051, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0065, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0601, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.00211157463490963
# -----------------------------------------------------------------------------
# Epoch: 1101
# error of u1: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0044, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0588, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001718043931759894
# -----------------------------------------------------------------------------
# Epoch: 1151
# error of u1: tensor(0.0082, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0037, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0595, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.011262679472565651
# -----------------------------------------------------------------------------
# Epoch: 1201
# error of u1: tensor(0.0043, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0095, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0593, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.007265129126608372
# -----------------------------------------------------------------------------
# Epoch: 1251
# error of u1: tensor(0.0031, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0044, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0588, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.003984438255429268
# -----------------------------------------------------------------------------
# Epoch: 1301
# error of u1: tensor(0.0038, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0064, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0557, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0052968766540288925
# -----------------------------------------------------------------------------
# Epoch: 1351
# error of u1: tensor(0.0037, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0046, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0573, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002920729573816061
# -----------------------------------------------------------------------------
# Epoch: 1401
# error of u1: tensor(0.0042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0565, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.006149607244879007
# -----------------------------------------------------------------------------
# Epoch: 1451
# error of u1: tensor(0.0143, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0572, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.005082181189209223
# -----------------------------------------------------------------------------
# Epoch: 1501
# error of u1: tensor(0.0040, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0563, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0030129386577755213
# -----------------------------------------------------------------------------
# Epoch: 1551
# error of u1: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0543, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.006105627398937941
# -----------------------------------------------------------------------------
# Epoch: 1601
# error of u1: tensor(0.0070, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0048, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0543, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.004329476971179247
# -----------------------------------------------------------------------------
# Epoch: 1651
# error of u1: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0532, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.004197660833597183
# -----------------------------------------------------------------------------
# Epoch: 1701
# error of u1: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0519, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0025424142368137836
# -----------------------------------------------------------------------------
# Epoch: 1751
# error of u1: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0038, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0525, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013389423256739974
# -----------------------------------------------------------------------------
# Epoch: 1801
# error of u1: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0521, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0023582098074257374
# -----------------------------------------------------------------------------
# Epoch: 1851
# error of u1: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0071, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0521, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.004098388832062483
# -----------------------------------------------------------------------------
# Epoch: 1901
# error of u1: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0045, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0514, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002505284734070301
# -----------------------------------------------------------------------------
# Epoch: 1951
# error of u1: tensor(0.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0521, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0025977722834795713
# -----------------------------------------------------------------------------
# Epoch: 2001
# error of u1: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0524, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.004081490449607372
# -----------------------------------------------------------------------------
# Epoch: 2051
# error of u1: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0074, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0524, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0028473963029682636
# -----------------------------------------------------------------------------
# Epoch: 2101
# error of u1: tensor(0.0046, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0499, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002400354016572237
# -----------------------------------------------------------------------------
# Epoch: 2151
# error of u1: tensor(0.0029, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0497, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002740772208198905
# -----------------------------------------------------------------------------
# Epoch: 2201
# error of u1: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0507, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.003814446274191141
# -----------------------------------------------------------------------------
# Epoch: 2251
# error of u1: tensor(0.0033, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0491, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0017092740163207054
# -----------------------------------------------------------------------------
# Epoch: 2301
# error of u1: tensor(0.0032, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0034, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0496, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002513128099963069
# -----------------------------------------------------------------------------
# Epoch: 2351
# error of u1: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0500, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0043824780732393265
# -----------------------------------------------------------------------------
# Epoch: 2401
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0506, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002523653209209442
# -----------------------------------------------------------------------------
# Epoch: 2451
# error of u1: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0031, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0490, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0032524324487894773
# -----------------------------------------------------------------------------
# Epoch: 2501
# error of u1: tensor(0.0046, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0502, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0021609929390251637
# -----------------------------------------------------------------------------
# Epoch: 2551
# error of u1: tensor(0.0052, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0474, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002516157226637006
# -----------------------------------------------------------------------------
# Epoch: 2601
# error of u1: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0485, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0022385690826922655
# -----------------------------------------------------------------------------
# Epoch: 2651
# error of u1: tensor(0.0038, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0479, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.004274715669453144
# -----------------------------------------------------------------------------
# Epoch: 2701
# error of u1: tensor(0.0037, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0478, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002442621625959873
# -----------------------------------------------------------------------------
# Epoch: 2751
# error of u1: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0474, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0022079492919147015
# -----------------------------------------------------------------------------
# Epoch: 2801
# error of u1: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0029, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0462, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002199408831074834
# -----------------------------------------------------------------------------
# Epoch: 2851
# error of u1: tensor(0.0029, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0471, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0028588310815393925
# -----------------------------------------------------------------------------
# Epoch: 2901
# error of u1: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0469, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001910977647639811
# -----------------------------------------------------------------------------
# Epoch: 2951
# error of u1: tensor(0.0011, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0467, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001473524491302669
# -----------------------------------------------------------------------------
# Epoch: 3001
# error of u1: tensor(0.0040, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0455, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0017456149216741323
# -----------------------------------------------------------------------------
# Epoch: 3051
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0033, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0458, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013860702747479081
# -----------------------------------------------------------------------------
# Epoch: 3101
# error of u1: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0466, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002413078211247921
# -----------------------------------------------------------------------------
# Epoch: 3151
# error of u1: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0011, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0459, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0026208730414509773
# -----------------------------------------------------------------------------
# Epoch: 3201
# error of u1: tensor(0.0005, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0462, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0016484607476741076
# -----------------------------------------------------------------------------
# Epoch: 3251
# error of u1: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0033, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0464, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0015877896221354604
# -----------------------------------------------------------------------------
# Epoch: 3301
# error of u1: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0451, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0012664260575547814
# -----------------------------------------------------------------------------
# Epoch: 3351
# error of u1: tensor(0.0039, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0035, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0453, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0031014292035251856
# -----------------------------------------------------------------------------
# Epoch: 3401
# error of u1: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0452, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013864797074347734
# -----------------------------------------------------------------------------
# Epoch: 3451
# error of u1: tensor(0.0042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0446, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0022677555680274963
# -----------------------------------------------------------------------------
# Epoch: 3501
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0457, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0025197293143719435
# -----------------------------------------------------------------------------
# Epoch: 3551
# error of u1: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0468, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001986915245652199
# -----------------------------------------------------------------------------
# Epoch: 3601
# error of u1: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0009, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0446, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018980269087478518
# -----------------------------------------------------------------------------
# Epoch: 3651
# error of u1: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0448, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018301868112757802
# -----------------------------------------------------------------------------
# Epoch: 3701
# error of u1: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0463, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0014849918661639094
# -----------------------------------------------------------------------------
# Epoch: 3751
# error of u1: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0446, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018527056090533733
# -----------------------------------------------------------------------------
# Epoch: 3801
# error of u1: tensor(0.0061, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0455, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0025433595292270184
# -----------------------------------------------------------------------------
# Epoch: 3851
# error of u1: tensor(0.0031, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0048, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0442, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0025759264826774597
# -----------------------------------------------------------------------------
# Epoch: 3901
# error of u1: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0438, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0016984428511932492
# -----------------------------------------------------------------------------
# Epoch: 3951
# error of u1: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0009, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0434, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0012174432631582022
# -----------------------------------------------------------------------------
# Epoch: 4001
# error of u1: tensor(0.0029, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0451, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.003192187286913395
# -----------------------------------------------------------------------------
# Epoch: 4051
# error of u1: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0035, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0438, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0031766286119818687
# -----------------------------------------------------------------------------
# Epoch: 4101
# error of u1: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0433, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0026989004109054804
# -----------------------------------------------------------------------------
# Epoch: 4151
# error of u1: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0008, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0446, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018512142123654485
# -----------------------------------------------------------------------------
# Epoch: 4201
# error of u1: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0453, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013522561639547348
# -----------------------------------------------------------------------------
# Epoch: 4251
# error of u1: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0456, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002414460526779294
# -----------------------------------------------------------------------------
# Epoch: 4301
# error of u1: tensor(0.0007, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0441, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001825340325012803
# -----------------------------------------------------------------------------
# Epoch: 4351
# error of u1: tensor(0.0043, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0441, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001319143339060247
# -----------------------------------------------------------------------------
# Epoch: 4401
# error of u1: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0036, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0438, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002036705845966935
# -----------------------------------------------------------------------------
# Epoch: 4451
# error of u1: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0433, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018063022289425135
# -----------------------------------------------------------------------------
# Epoch: 4501
# error of u1: tensor(0.0008, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0431, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0009299602825194597
# -----------------------------------------------------------------------------
# Epoch: 4551
# error of u1: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0034, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0450, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0009998283348977566
# -----------------------------------------------------------------------------
# Epoch: 4601
# error of u1: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0433, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0011339203920215368
# -----------------------------------------------------------------------------
# Epoch: 4651
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0442, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0015797667438164353
# -----------------------------------------------------------------------------
# Epoch: 4701
# error of u1: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0446, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0009499094448983669
# -----------------------------------------------------------------------------
# Epoch: 4751
# error of u1: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0432, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0011295665754005313
# -----------------------------------------------------------------------------
# Epoch: 4801
# error of u1: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0011, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0442, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0023807594552636147
# -----------------------------------------------------------------------------
# Epoch: 4851
# error of u1: tensor(0.0045, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0437, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0017426832346245646
# -----------------------------------------------------------------------------
# Epoch: 4901
# error of u1: tensor(0.0040, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0437, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001886293524876237
# -----------------------------------------------------------------------------
# Epoch: 4951
# error of u1: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0036, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0434, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0029666810296475887
# -----------------------------------------------------------------------------
# Epoch: 5001
# error of u1: tensor(0.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0035, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0441, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0008330372511409223
# -----------------------------------------------------------------------------
# Epoch: 5051
# error of u1: tensor(0.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0445, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0015700925141572952
# -----------------------------------------------------------------------------
# Epoch: 5101
# error of u1: tensor(0.0042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0428, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002246930729597807
# -----------------------------------------------------------------------------
# Epoch: 5151
# error of u1: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0450, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0012678415514528751
# -----------------------------------------------------------------------------
# Epoch: 5201
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0037, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0456, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0016565596451982856
# -----------------------------------------------------------------------------
# Epoch: 5251
# error of u1: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0432, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0024015172384679317
# -----------------------------------------------------------------------------
# Epoch: 5301
# error of u1: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0434, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0014725907240062952
# -----------------------------------------------------------------------------
# Epoch: 5351
# error of u1: tensor(0.0041, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0448, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010581365786492825
# -----------------------------------------------------------------------------
# Epoch: 5401
# error of u1: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0033, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0439, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001048412872478366
# -----------------------------------------------------------------------------
# Epoch: 5451
# error of u1: tensor(0.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0432, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0015319897793233395
# -----------------------------------------------------------------------------
# Epoch: 5501
# error of u1: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0433, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002930721268057823
# -----------------------------------------------------------------------------
# Epoch: 5551
# error of u1: tensor(0.0008, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0029, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0444, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0024773075710982084
# -----------------------------------------------------------------------------
# Epoch: 5601
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0437, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0009800223633646965
# -----------------------------------------------------------------------------
# Epoch: 5651
# error of u1: tensor(0.0042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0430, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013570840237662196
# -----------------------------------------------------------------------------
# Epoch: 5701
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0438, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018683266825973988
# -----------------------------------------------------------------------------
# Epoch: 5751
# error of u1: tensor(0.0042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0440, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010754879331216216
# -----------------------------------------------------------------------------
# Epoch: 5801
# error of u1: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0453, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001382546266540885
# -----------------------------------------------------------------------------
# Epoch: 5851
# error of u1: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0449, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0011558308033272624
# -----------------------------------------------------------------------------
# Epoch: 5901
# error of u1: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0439, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0007044271333143115
# -----------------------------------------------------------------------------
# Epoch: 5951
# error of u1: tensor(0.0033, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0443, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0011512573109939694
# -----------------------------------------------------------------------------
# Epoch: 6001
# error of u1: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0435, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005203717155382037
# -----------------------------------------------------------------------------
# Epoch: 6051
# error of u1: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0447, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0015970718814060092
# -----------------------------------------------------------------------------
# Epoch: 6101
# error of u1: tensor(0.0011, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0428, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002127378946170211
# -----------------------------------------------------------------------------
# Epoch: 6151
# error of u1: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0436, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010515502654016018
# -----------------------------------------------------------------------------
# Epoch: 6201
# error of u1: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0449, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002170765306800604
# -----------------------------------------------------------------------------
# Epoch: 6251
# error of u1: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0448, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006237257039174438
# -----------------------------------------------------------------------------
# Epoch: 6301
# error of u1: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0437, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010893343714997172
# -----------------------------------------------------------------------------
# Epoch: 6351
# error of u1: tensor(0.0036, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0442, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0012424590531736612
# -----------------------------------------------------------------------------
# Epoch: 6401
# error of u1: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0033, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0451, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010669694747775793
# -----------------------------------------------------------------------------
# Epoch: 6451
# error of u1: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0433, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0009192039724439383
# -----------------------------------------------------------------------------
# Epoch: 6501
# error of u1: tensor(0.0035, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0444, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0016089227283373475
# -----------------------------------------------------------------------------
# Epoch: 6551
# error of u1: tensor(0.0042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0009, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0445, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005817681667394936
# -----------------------------------------------------------------------------
# Epoch: 6601
# error of u1: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0442, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013562605017796159
# -----------------------------------------------------------------------------
# Epoch: 6651
# error of u1: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0433, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0025852343533188105
# -----------------------------------------------------------------------------
# Epoch: 6701
# error of u1: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0451, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.00116353714838624
# -----------------------------------------------------------------------------
# Epoch: 6751
# error of u1: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0456, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001362520270049572
# -----------------------------------------------------------------------------
# Epoch: 6801
# error of u1: tensor(0.0011, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0453, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018990259850397706
# -----------------------------------------------------------------------------
# Epoch: 6851
# error of u1: tensor(0.0041, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0440, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0023706459905952215
# -----------------------------------------------------------------------------
# Epoch: 6901
# error of u1: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0447, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018262325320392847
# -----------------------------------------------------------------------------
# Epoch: 6951
# error of u1: tensor(0.0011, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0453, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018025200115516782
# -----------------------------------------------------------------------------
# Epoch: 7001
# error of u1: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0029, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0448, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0022706477902829647
# -----------------------------------------------------------------------------
# Epoch: 7051
# error of u1: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0443, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010210495674982667
# -----------------------------------------------------------------------------
# Epoch: 7101
# error of u1: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0457, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018745244015008211
# -----------------------------------------------------------------------------
# Epoch: 7151
# error of u1: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0461, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0018233023583889008
# -----------------------------------------------------------------------------
# Epoch: 7201
# error of u1: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0443, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.00277119898237288
# -----------------------------------------------------------------------------
# Epoch: 7251
# error of u1: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0455, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0008623741450719535
# -----------------------------------------------------------------------------
# Epoch: 7301
# error of u1: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# ...
# error of u2: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0736, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.000784513889811933
# -----------------------------------------------------------------------------
# Epoch: 27601
# error of u1: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0011, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0736, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013722324511036277
# -----------------------------------------------------------------------------
# Epoch: 27651
# error of u1: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0032, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0739, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.002791706472635269
# -----------------------------------------------------------------------------
# Epoch: 27701
# error of u1: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0730, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005543230217881501
# -----------------------------------------------------------------------------
# Epoch: 27751
# error of u1: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0734, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.000874215504154563
# -----------------------------------------------------------------------------
# Epoch: 27801
# error of u1: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0007, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0737, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006618885672651231
# -----------------------------------------------------------------------------
# Epoch: 27851
# error of u1: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0732, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.00115091516636312
# -----------------------------------------------------------------------------
# Epoch: 27901
# error of u1: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0739, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006376674282364547
# -----------------------------------------------------------------------------
# Epoch: 27951
# error of u1: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0731, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001197742996737361
# -----------------------------------------------------------------------------
# Epoch: 28001
# error of u1: tensor(0.0006, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0009, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0741, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005507830064743757
# -----------------------------------------------------------------------------
# Epoch: 28051
# error of u1: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0735, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0008406229317188263
# -----------------------------------------------------------------------------
# Epoch: 28101
# error of u1: tensor(0.0011, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0740, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001342763309367001
# -----------------------------------------------------------------------------
# Epoch: 28151
# error of u1: tensor(0.0031, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0035, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0742, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005553544033318758
# -----------------------------------------------------------------------------
# Epoch: 28201
# error of u1: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0744, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010292613878846169
# -----------------------------------------------------------------------------
# Epoch: 28251
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0028, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0740, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0007054655579850078
# -----------------------------------------------------------------------------
# Epoch: 28301
# error of u1: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0741, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006435196846723557
# -----------------------------------------------------------------------------
# Epoch: 28351
# error of u1: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0745, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0012745626736432314
# -----------------------------------------------------------------------------
# Epoch: 28401
# error of u1: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0747, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005787292029708624
# -----------------------------------------------------------------------------
# Epoch: 28451
# error of u1: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0743, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006684062536805868
# -----------------------------------------------------------------------------
# Epoch: 28501
# error of u1: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0032, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0744, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0011746477102860808
# -----------------------------------------------------------------------------
# Epoch: 28551
# error of u1: tensor(0.0039, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0745, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013248862233012915
# -----------------------------------------------------------------------------
# Epoch: 28601
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0747, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005037067458033562
# -----------------------------------------------------------------------------
# Epoch: 28651
# error of u1: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0746, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006178826442919672
# -----------------------------------------------------------------------------
# Epoch: 28701
# error of u1: tensor(0.0031, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0747, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010953597957268357
# -----------------------------------------------------------------------------
# Epoch: 28751
# error of u1: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0744, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.000753579952288419
# -----------------------------------------------------------------------------
# Epoch: 28801
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0748, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0008801621152088046
# -----------------------------------------------------------------------------
# Epoch: 28851
# error of u1: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0746, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005448051379062235
# -----------------------------------------------------------------------------
# Epoch: 28901
# error of u1: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0013, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0754, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0012055482948198915
# -----------------------------------------------------------------------------
# Epoch: 28951
# error of u1: tensor(0.0009, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0746, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0007138611981645226
# -----------------------------------------------------------------------------
# Epoch: 29001
# error of u1: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0756, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0013688039034605026
# -----------------------------------------------------------------------------
# Epoch: 29051
# error of u1: tensor(0.0008, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0012, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0748, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.000687404302880168
# -----------------------------------------------------------------------------
# Epoch: 29101
# error of u1: tensor(0.0005, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0752, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001557155279442668
# -----------------------------------------------------------------------------
# Epoch: 29151
# error of u1: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0006, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0753, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.000831372570246458
# -----------------------------------------------------------------------------
# Epoch: 29201
# error of u1: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0750, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006423537852242589
# -----------------------------------------------------------------------------
# Epoch: 29251
# error of u1: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0008, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0750, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006415483076125383
# -----------------------------------------------------------------------------
# Epoch: 29301
# error of u1: tensor(0.0006, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0030, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0747, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.000898795435205102
# -----------------------------------------------------------------------------
# Epoch: 29351
# error of u1: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0760, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0007048387196846306
# -----------------------------------------------------------------------------
# Epoch: 29401
# error of u1: tensor(0.0027, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0041, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0755, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.00105245690792799
# -----------------------------------------------------------------------------
# Epoch: 29451
# error of u1: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0032, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0751, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0015441861469298601
# -----------------------------------------------------------------------------
# Epoch: 29501
# error of u1: tensor(0.0009, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0021, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0759, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005227389628998935
# -----------------------------------------------------------------------------
# Epoch: 29551
# error of u1: tensor(0.0014, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0025, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0758, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0007551545859314501
# -----------------------------------------------------------------------------
# Epoch: 29601
# error of u1: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0752, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0006914573605172336
# -----------------------------------------------------------------------------
# Epoch: 29651
# error of u1: tensor(0.0007, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0008, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0762, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0009725653217174113
# -----------------------------------------------------------------------------
# Epoch: 29701
# error of u1: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0757, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0005840907688252628
# -----------------------------------------------------------------------------
# Epoch: 29751
# error of u1: tensor(0.0010, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0020, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0758, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010907419491559267
# -----------------------------------------------------------------------------
# Epoch: 29801
# error of u1: tensor(0.0026, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0024, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0756, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.001647035125643015
# -----------------------------------------------------------------------------
# Epoch: 29851
# error of u1: tensor(0.0016, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0015, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0762, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.00042449598549865186
# -----------------------------------------------------------------------------
# Epoch: 29901
# error of u1: tensor(0.0023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0019, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0758, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0010419134050607681
# -----------------------------------------------------------------------------
# Epoch: 29951
# error of u1: tensor(0.0017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0018, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.0761, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.0007352439570240676

# %%
import matplotlib.pyplot as plt

plt.plot(error_pinn_list1, label='Error of u1')
plt.plot(error_pinn_list2, label='Error of u2')
plt.plot(error_pinn_list3, label='Error of P')

plt.title('PINN method for p-Stokes Equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Error')
plt.yscale('log')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(loss_list2, label='PINN Loss')

#plt.title('DRM for p-Stokes Equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Loss')
plt.yscale('log')

plt.legend()

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import torch
from torch.autograd import Variable

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
r=1

# 데이터 생성
x_collocation = []
y_collocation = []
p_collocation = []

theta = np.linspace(0, 2*np.pi, 120)
x = np.cos(theta)
y = np.sin(theta)

X, Y = np.meshgrid(x, y)

pt_x = Variable(torch.from_numpy(X).float(), requires_grad=False).to(device)
pt_y = Variable(torch.from_numpy(Y).float(), requires_grad=False).to(device)

pt_x = pt_x.reshape(-1,1)
pt_y = pt_y.reshape(-1,1)
pt_p = 2*torch.ones_like(pt_x) + 2   #2 < p < 4

# 신경망 예측
Predict1 = net_pinn_1(pt_x, pt_y, pt_p)
Predict2 = net_pinn_2(pt_x, pt_y, pt_p)
Predict3 = net_pinn_P(pt_x, pt_y, pt_p)
Truesol1 = k*pt_y * (r**2 - pt_x**2 - pt_y**2)
Truesol2 = -k*pt_x * (r**2 - pt_x**2 - pt_y**2)
Truesol3 = 3*(pt_x + pt_y)

Predict1 = Predict1.data.cpu().numpy()
Predict2 = Predict2.data.cpu().numpy()
Predict3 = Predict3.data.cpu().numpy()
Truesol1 = Truesol1.data.cpu().numpy()
Truesol2 = Truesol2.data.cpu().numpy()
Truesol3 = Truesol3.data.cpu().numpy()

PR_u1 = Predict1.reshape(X.shape)
PR_u2 = Predict2.reshape(X.shape)
PR_P = Predict3.reshape(X.shape)
Truesol1 = Truesol1.reshape(X.shape)
Truesol2 = Truesol2.reshape(X.shape)
Truesol3 = Truesol3.reshape(X.shape)

# 마스크 생성

mask = (X**2 + Y**2 > r**2)
PR_u1[mask] = 0
PR_u2[mask] = 0
PR_P[mask] = 0
Truesol1[mask] = 0
Truesol2[mask] = 0
Truesol3[mask] = 0

# 3D 표면 플롯
surf = ax.plot_surface(X, Y, PR_P, cmap=cm.coolwarm, linewidth=0, antialiased=False)
#surf = ax.plot_surface(X, Y, Truesol3, cmap=cm.coolwarm, linewidth=0, antialiased=False)
#surf = ax.plot_surface(X, Y, (Truesol3 - PR_P), cmap=cm.coolwarm, linewidth=0, antialiased=False)

# 색상 바 추가
fig.colorbar(surf, shrink=0.5, aspect=4)
#plt.title('Solution - Prediction for p=3 (P)')

# z축 범위 및 눈금 설정
#ax.set_zlim(0, 1)  # z축의 값 범위를 설정
#ax.set_zticks(np.arange(0, 1, 0.1))  # z축 눈금을 -0.15부터 0.15까지 0.05 간격으로 설정

plt.show()

# %% [markdown]
# # DRM for p-Stokes Equation

# %%
M = 100

T = True
F = False

class Net_2D(nn.Module):
    def __init__(self):
        super(Net_2D, self).__init__()
        torch.manual_seed(1234) # Fix Initial_Parameter
        self.hidden_layer1 = nn.Linear(3,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer2 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer3 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer4 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        #self.hidden_layer5 = nn.Linear(M,M, bias = T)
        #torch.manual_seed(1234)
        self.output_layer = nn.Linear(M,1, bias = T)

    def forward(self, x,y,p):
        inputs = torch.cat([x,y,p],axis=1)
        layer1_out = activation(self.hidden_layer1(inputs))
        layer2_out = activation(self.hidden_layer2(layer1_out))
        layer3_out = activation(self.hidden_layer3(layer2_out))
        layer4_out = activation(self.hidden_layer4(layer3_out))
        #layer5_out = activation(self.hidden_layer5(layer4_out))
        output = self.output_layer(layer4_out)

        return output

class Net_2D_f(nn.Module):
    def __init__(self):
        super(Net_2D_f, self).__init__()
        torch.manual_seed(1234) # Fix Initial_Parameter
        self.hidden_layer1 = nn.Linear(3,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer2 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer3 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        self.hidden_layer4 = nn.Linear(M,M, bias = T)
        torch.manual_seed(1234)
        #self.hidden_layer5 = nn.Linear(M,M, bias = T)
        #torch.manual_seed(1234)
        self.output_layer = nn.Linear(M,1, bias = T)

    def forward(self, x,y,p):
        inputs = torch.cat([x,y,p],axis=1)
        layer1_out = activation_(self.hidden_layer1(inputs))
        layer2_out = activation_(self.hidden_layer2(layer1_out))
        layer3_out = activation_(self.hidden_layer3(layer2_out))
        layer4_out = activation_(self.hidden_layer4(layer3_out))
        #layer5_out = activation(self.hidden_layer5(layer4_out))
        output = self.output_layer(layer4_out)

        return output

# %%
mse_cost_function = torch.nn.MSELoss() #MSE Function can be shared

net_drm_1 = Net_2D()
net_drm_1 = net_drm_1.to(device)

net_drm_2 = Net_2D()
net_drm_2 = net_drm_2.to(device)

net_drm_P = Net_2D_f()
net_drm_P = net_drm_P.to(device)

optimizer1_d = optim.SOAP(net_drm_1.parameters(),lr=0.001)
optimizer2_d = optim.SOAP(net_drm_2.parameters(),lr=0.001)
optimizerP_d = optim.SOAP(net_drm_P.parameters(),lr=0.001)

# %%
def f3(x,y,p,x_bdy,y_bdy, f1,f2, net1, net2, netP):
    ##------------------------ Network output -------------------------------
    P = netP(x,y,p)
    w = net1(x,y,p)
    v = net2(x,y,p)

    w_bdy = net1(x_bdy,y_bdy,p)
    v_bdy = net2(x_bdy,y_bdy,p)
    ##--------------------Differentiation--------------------------

    P_x = torch.autograd.grad(P.sum(), x, create_graph=True)[0]
    P_y = torch.autograd.grad(P.sum(), y, create_graph=True)[0]

    w_x = torch.autograd.grad(w.sum(), x, create_graph=True)[0]
    w_y = torch.autograd.grad(w.sum(), y, create_graph=True)[0]

    v_x = torch.autograd.grad(v.sum(), x, create_graph=True)[0]
    v_y = torch.autograd.grad(v.sum(), y, create_graph=True)[0]

    AbsDu = (w_x**2 + w_y**2 + v_x**2 + v_y**2)**((p-2)/2)

    div11 = torch.autograd.grad((AbsDu*w_x).sum(), x, create_graph=True)[0]
    div12 = torch.autograd.grad((AbsDu*w_y).sum(), y, create_graph=True)[0]
    div21 = torch.autograd.grad((AbsDu*v_x).sum(), x, create_graph=True)[0]
    div22 = torch.autograd.grad((AbsDu*v_y).sum(), y, create_graph=True)[0]

    ##-----------------------Calculate Variational----------------------------
    Integral = (P.mean())**2

    Bdy = (w_bdy**2 + v_bdy**2).mean()

    Var = ((1/p)*(w_x**2 + w_y**2 + v_x**2 + v_y**2)**(p/2) - (f1*w + f2*v)).mean()

    Div = ((w_x + v_y)**2).mean()
    #__

    return Var + Integral + 1000*Bdy + 1000*Div

# %%
# Function to check if a point is inside the circle
def is_inside(x, y):

    return x**2 + y**2 < 1


# Generate random points inside the domain
def generate_random_points(n_points=1000):
    points = []
    while len(points) < n_points:
        x = np.random.uniform(-1, 1)
        y = np.random.uniform(-1, 1)
        if is_inside(x, y):
            points.append((x, y))
    return np.array(points)

# Example usage
random_points = generate_random_points(2000)

x_coords_ = random_points[:, 0].reshape(-1, 1)
y_coords_ = random_points[:, 1].reshape(-1, 1)
p_coords_ = (2*np.random.rand(len(x_coords_)) + 2).reshape(-1, 1)   #2 < p < 4

pt_x_collocation = Variable(torch.from_numpy(x_coords_).float(), requires_grad=True).to(device)
pt_y_collocation = Variable(torch.from_numpy(y_coords_).float(), requires_grad=True).to(device)
pt_p_collocation = Variable(torch.from_numpy(p_coords_).float(), requires_grad=True).to(device)

#-----------------------------set F-------------------------------------------------

pt_x = Variable(torch.from_numpy(x_coords_).float(), requires_grad=False).to(device)
pt_y = Variable(torch.from_numpy(y_coords_).float(), requires_grad=False).to(device)
pt_p = Variable(torch.from_numpy(p_coords_).float(), requires_grad=False).to(device)

pt_Q = k**(pt_p - 2)*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-2)/2)
pt_Q_x = k**(pt_p - 2)*((pt_p-2)/2*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-4)/2) * (16*(pt_x)*(pt_y**2) - 4*pt_x*(1 - pt_x**2 - 3*(pt_y**2)) + 12*pt_x*(-1 + 3*(pt_x**2) + pt_y**2)))
pt_Q_y = k**(pt_p - 2)*((pt_p-2)/2*(8*(pt_x**2)*(pt_y**2) + (1 - pt_x**2 - 3*(pt_y**2))**2 + (-1 + 3*(pt_x**2) + pt_y**2)**2)**((pt_p-4)/2) * (16*(pt_x**2)*(pt_y) - 12*pt_y*(1 - pt_x**2 - 3*(pt_y**2)) + 4*pt_y*(-1 + 3*(pt_x**2) + pt_y**2)))

F1 = -(pt_Q_x*(-2*pt_x*pt_y) + pt_Q*(-2*pt_y) + pt_Q_y*(1 - pt_x**2 - 3*pt_y**2) + pt_Q*(-6*pt_y)) + 3
F2 = -(pt_Q_x*(-1 + 3*pt_x**2 + pt_y**2) + pt_Q*(6*pt_x) + pt_Q_y*(2*pt_x*pt_y) + pt_Q*(2*pt_x)) + 3

# %%
## Boundary

theta1 = np.linspace(0, 2*np.pi, 2000)

x_coords1 = np.cos(theta1).reshape(-1, 1)
y_coords1 = np.sin(theta1).reshape(-1, 1)

bdy_x = Variable(torch.from_numpy(x_coords1).float(), requires_grad=True).to(device)
bdy_y = Variable(torch.from_numpy(y_coords1).float(), requires_grad=True).to(device)

# x_coords1

# %%
## u solution
sol_u = k*(pt_y*(1 - pt_x**2 - pt_y**2))

#v solution
sol_v = k*(-pt_x*(1 - pt_x**2 - pt_y**2))

## P solution
sol_P = 3*(pt_x + pt_y)

# %%
error_drm_list1 = []
error_drm_list2 = []
error_drm_list3 = []
loss_list3 = []

previous_validation_loss = 99999999.0
epoch = 0

while epoch < 30000:
    optimizer1_d.zero_grad()
    optimizer2_d.zero_grad()
    optimizerP_d.zero_grad()

##------------------------------------Compute Loss-----------------------------------------##

    loss = 1*f3(pt_x_collocation, pt_y_collocation, pt_p_collocation, bdy_x, bdy_y, F1,F2, net_drm_1,net_drm_2,net_drm_P)

##------------------------------------Optimize Loss-----------------------------------------##

    loss.backward()
    optimizer1_d.step()
    optimizer2_d.step()
    optimizerP_d.step()

    epoch += 1

##----------------------------Adaptive learningrate-----------------------------##

    if (epoch) % 50 == 1:
        print("-----------------------------------------------------------------------------")
        print("Epoch:",epoch)

        gap11 = torch.sqrt((((sol_u - net_drm_1(pt_x, pt_y, pt_p))**2).mean())/((sol_u)**2).mean())
        gap22 = torch.sqrt((((sol_v - net_drm_2(pt_x, pt_y, pt_p))**2).mean())/((sol_v)**2).mean())
        gap33 = torch.sqrt((((sol_P - net_drm_P(pt_x, pt_y, pt_p))**2).mean())/((sol_P)**2).mean())

        print('error of u1:',gap11)
        print('error of u2:',gap22)
        print('error of P:',gap33)

        print("Loss :", (loss).item())
        error_drm_list1.append(gap11.item())
        error_drm_list2.append(gap22.item())
        error_drm_list3.append(gap33.item())
        loss_list3.append(loss.item())
# Out:
# -----------------------------------------------------------------------------
# Epoch: 1
# error of u1: tensor(1.0042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(1.0079, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9998, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : 0.12268874794244766
# -----------------------------------------------------------------------------
# Epoch: 51
# error of u1: tensor(0.9926, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9931, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.02336922101676464
# -----------------------------------------------------------------------------
# Epoch: 101
# error of u1: tensor(0.9911, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9918, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.029568322002887726
# -----------------------------------------------------------------------------
# Epoch: 151
# error of u1: tensor(0.9902, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9909, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.033485572785139084
# -----------------------------------------------------------------------------
# Epoch: 201
# error of u1: tensor(0.9875, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9866, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.03988797962665558
# -----------------------------------------------------------------------------
# Epoch: 251
# error of u1: tensor(0.9813, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9785, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.052462123334407806
# -----------------------------------------------------------------------------
# Epoch: 301
# error of u1: tensor(0.9685, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9616, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.07840009778738022
# -----------------------------------------------------------------------------
# Epoch: 351
# error of u1: tensor(0.9385, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.9288, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.13233356177806854
# -----------------------------------------------------------------------------
# Epoch: 401
# error of u1: tensor(0.8746, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.8697, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.24237971007823944
# -----------------------------------------------------------------------------
# Epoch: 451
# error of u1: tensor(0.7525, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.7559, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.44717317819595337
# -----------------------------------------------------------------------------
# Epoch: 501
# error of u1: tensor(0.5534, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.5606, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(0.9999, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -0.7575037479400635
# -----------------------------------------------------------------------------
# Epoch: 551
# error of u1: tensor(0.3047, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3117, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.064050555229187
# -----------------------------------------------------------------------------
# Epoch: 601
# error of u1: tensor(0.1281, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1340, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2001527547836304
# -----------------------------------------------------------------------------
# Epoch: 651
# error of u1: tensor(0.0712, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0671, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2262675762176514
# -----------------------------------------------------------------------------
# Epoch: 701
# error of u1: tensor(0.0460, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0376, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2382842302322388
# -----------------------------------------------------------------------------
# Epoch: 751
# error of u1: tensor(0.0464, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0355, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2423332929611206
# -----------------------------------------------------------------------------
# Epoch: 801
# error of u1: tensor(0.0474, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0380, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.244323492050171
# -----------------------------------------------------------------------------
# Epoch: 851
# error of u1: tensor(0.0478, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0382, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2479370832443237
# -----------------------------------------------------------------------------
# Epoch: 901
# error of u1: tensor(0.0435, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0386, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.247854232788086
# -----------------------------------------------------------------------------
# Epoch: 951
# error of u1: tensor(0.0433, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0372, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2506507635116577
# -----------------------------------------------------------------------------
# Epoch: 1001
# error of u1: tensor(0.0418, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0365, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2510333061218262
# -----------------------------------------------------------------------------
# Epoch: 1051
# error of u1: tensor(0.0389, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0391, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2520071268081665
# -----------------------------------------------------------------------------
# Epoch: 1101
# error of u1: tensor(0.0402, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0410, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2537466287612915
# -----------------------------------------------------------------------------
# Epoch: 1151
# error of u1: tensor(0.0411, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0410, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2532306909561157
# -----------------------------------------------------------------------------
# Epoch: 1201
# error of u1: tensor(0.0406, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0429, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2553868293762207
# -----------------------------------------------------------------------------
# Epoch: 1251
# error of u1: tensor(0.0406, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0447, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2561793327331543
# -----------------------------------------------------------------------------
# Epoch: 1301
# error of u1: tensor(0.0419, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0448, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2574597597122192
# -----------------------------------------------------------------------------
# Epoch: 1351
# error of u1: tensor(0.0420, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0469, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.256823182106018
# -----------------------------------------------------------------------------
# Epoch: 1401
# error of u1: tensor(0.0412, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0470, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.258926272392273
# -----------------------------------------------------------------------------
# Epoch: 1451
# error of u1: tensor(0.0439, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0496, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2581602334976196
# -----------------------------------------------------------------------------
# Epoch: 1501
# error of u1: tensor(0.0446, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0509, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.260222315788269
# -----------------------------------------------------------------------------
# Epoch: 1551
# error of u1: tensor(0.0453, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0528, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2614972591400146
# -----------------------------------------------------------------------------
# Epoch: 1601
# error of u1: tensor(0.0488, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0562, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2615547180175781
# -----------------------------------------------------------------------------
# Epoch: 1651
# error of u1: tensor(0.0511, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0545, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2622660398483276
# -----------------------------------------------------------------------------
# Epoch: 1701
# error of u1: tensor(0.0508, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0562, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2637674808502197
# -----------------------------------------------------------------------------
# Epoch: 1751
# error of u1: tensor(0.0530, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0591, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2644479274749756
# -----------------------------------------------------------------------------
# Epoch: 1801
# error of u1: tensor(0.0532, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0600, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.262463092803955
# -----------------------------------------------------------------------------
# Epoch: 1851
# error of u1: tensor(0.0536, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0587, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2653177976608276
# -----------------------------------------------------------------------------
# Epoch: 1901
# error of u1: tensor(0.0558, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0610, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2677708864212036
# -----------------------------------------------------------------------------
# Epoch: 1951
# error of u1: tensor(0.0595, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0633, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2677651643753052
# -----------------------------------------------------------------------------
# Epoch: 2001
# error of u1: tensor(0.0602, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0649, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2698055505752563
# -----------------------------------------------------------------------------
# Epoch: 2051
# error of u1: tensor(0.0596, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0658, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2699352502822876
# -----------------------------------------------------------------------------
# Epoch: 2101
# error of u1: tensor(0.0613, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0670, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.270507574081421
# -----------------------------------------------------------------------------
# Epoch: 2151
# error of u1: tensor(0.0629, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0656, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2725183963775635
# -----------------------------------------------------------------------------
# Epoch: 2201
# error of u1: tensor(0.0649, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0682, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.273705244064331
# -----------------------------------------------------------------------------
# Epoch: 2251
# error of u1: tensor(0.0671, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0709, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2721772193908691
# -----------------------------------------------------------------------------
# Epoch: 2301
# error of u1: tensor(0.0664, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0684, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2760474681854248
# -----------------------------------------------------------------------------
# Epoch: 2351
# error of u1: tensor(0.0678, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0703, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2770013809204102
# -----------------------------------------------------------------------------
# Epoch: 2401
# error of u1: tensor(0.0678, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0723, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2762231826782227
# -----------------------------------------------------------------------------
# Epoch: 2451
# error of u1: tensor(0.0685, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0720, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2780792713165283
# -----------------------------------------------------------------------------
# Epoch: 2501
# error of u1: tensor(0.0705, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0722, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2778328657150269
# -----------------------------------------------------------------------------
# Epoch: 2551
# error of u1: tensor(0.0708, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0731, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2791616916656494
# -----------------------------------------------------------------------------
# Epoch: 2601
# error of u1: tensor(0.0712, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0756, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2815271615982056
# -----------------------------------------------------------------------------
# Epoch: 2651
# error of u1: tensor(0.0709, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0759, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2821664810180664
# -----------------------------------------------------------------------------
# Epoch: 2701
# error of u1: tensor(0.0717, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0764, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2839202880859375
# -----------------------------------------------------------------------------
# Epoch: 2751
# error of u1: tensor(0.0725, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0787, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2859073877334595
# -----------------------------------------------------------------------------
# Epoch: 2801
# error of u1: tensor(0.0740, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0784, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2873318195343018
# -----------------------------------------------------------------------------
# Epoch: 2851
# error of u1: tensor(0.0751, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0804, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.288906216621399
# -----------------------------------------------------------------------------
# Epoch: 2901
# error of u1: tensor(0.0757, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0827, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2896227836608887
# -----------------------------------------------------------------------------
# Epoch: 2951
# error of u1: tensor(0.0771, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0841, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2912251949310303
# -----------------------------------------------------------------------------
# Epoch: 3001
# error of u1: tensor(0.0788, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0820, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2925821542739868
# -----------------------------------------------------------------------------
# Epoch: 3051
# error of u1: tensor(0.0793, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0839, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2953500747680664
# -----------------------------------------------------------------------------
# Epoch: 3101
# error of u1: tensor(0.0794, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0858, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2965848445892334
# -----------------------------------------------------------------------------
# Epoch: 3151
# error of u1: tensor(0.0811, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0872, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.297392725944519
# -----------------------------------------------------------------------------
# Epoch: 3201
# error of u1: tensor(0.0829, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0875, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2943974733352661
# -----------------------------------------------------------------------------
# Epoch: 3251
# error of u1: tensor(0.0834, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0909, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.2980914115905762
# -----------------------------------------------------------------------------
# Epoch: 3301
# error of u1: tensor(0.0839, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0923, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3006824254989624
# -----------------------------------------------------------------------------
# Epoch: 3351
# error of u1: tensor(0.0858, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0920, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3018466234207153
# -----------------------------------------------------------------------------
# Epoch: 3401
# error of u1: tensor(0.0869, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0923, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.304227590560913
# -----------------------------------------------------------------------------
# Epoch: 3451
# error of u1: tensor(0.0868, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0946, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3067110776901245
# -----------------------------------------------------------------------------
# Epoch: 3501
# error of u1: tensor(0.0886, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0951, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3086248636245728
# -----------------------------------------------------------------------------
# Epoch: 3551
# error of u1: tensor(0.0906, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0973, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3102257251739502
# -----------------------------------------------------------------------------
# Epoch: 3601
# error of u1: tensor(0.0908, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.0981, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3120261430740356
# -----------------------------------------------------------------------------
# Epoch: 3651
# error of u1: tensor(0.0925, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1007, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3014230728149414
# -----------------------------------------------------------------------------
# Epoch: 3701
# error of u1: tensor(0.0935, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1000, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3171744346618652
# -----------------------------------------------------------------------------
# Epoch: 3751
# error of u1: tensor(0.0949, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.318859338760376
# -----------------------------------------------------------------------------
# Epoch: 3801
# error of u1: tensor(0.0953, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1042, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3202158212661743
# -----------------------------------------------------------------------------
# Epoch: 3851
# error of u1: tensor(0.0969, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1057, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3191646337509155
# -----------------------------------------------------------------------------
# Epoch: 3901
# error of u1: tensor(0.0995, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1081, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3247735500335693
# -----------------------------------------------------------------------------
# Epoch: 3951
# error of u1: tensor(0.1004, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1090, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3250783681869507
# -----------------------------------------------------------------------------
# Epoch: 4001
# error of u1: tensor(0.1023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1112, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.328140139579773
# -----------------------------------------------------------------------------
# Epoch: 4051
# error of u1: tensor(0.1040, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1137, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3322032690048218
# -----------------------------------------------------------------------------
# Epoch: 4101
# error of u1: tensor(0.1064, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1142, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3332709074020386
# -----------------------------------------------------------------------------
# Epoch: 4151
# error of u1: tensor(0.1070, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1175, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3300228118896484
# -----------------------------------------------------------------------------
# Epoch: 4201
# error of u1: tensor(0.1102, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1217, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3363510370254517
# -----------------------------------------------------------------------------
# Epoch: 4251
# error of u1: tensor(0.1124, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1234, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.340833067893982
# -----------------------------------------------------------------------------
# Epoch: 4301
# error of u1: tensor(0.1134, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1257, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3448448181152344
# -----------------------------------------------------------------------------
# Epoch: 4351
# error of u1: tensor(0.1162, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1282, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3484928607940674
# -----------------------------------------------------------------------------
# Epoch: 4401
# error of u1: tensor(0.1173, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1319, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3540278673171997
# -----------------------------------------------------------------------------
# Epoch: 4451
# error of u1: tensor(0.1199, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1340, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3565140962600708
# -----------------------------------------------------------------------------
# Epoch: 4501
# error of u1: tensor(0.1216, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1372, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3591887950897217
# -----------------------------------------------------------------------------
# Epoch: 4551
# error of u1: tensor(0.1262, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1399, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3589924573898315
# -----------------------------------------------------------------------------
# Epoch: 4601
# error of u1: tensor(0.1281, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1451, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.365857720375061
# -----------------------------------------------------------------------------
# Epoch: 4651
# error of u1: tensor(0.1329, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1463, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3678499460220337
# -----------------------------------------------------------------------------
# Epoch: 4701
# error of u1: tensor(0.1343, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1491, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.363470196723938
# -----------------------------------------------------------------------------
# Epoch: 4751
# error of u1: tensor(0.1392, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1528, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3772658109664917
# -----------------------------------------------------------------------------
# Epoch: 4801
# error of u1: tensor(0.1401, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1571, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3808614015579224
# -----------------------------------------------------------------------------
# Epoch: 4851
# error of u1: tensor(0.1438, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1575, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3841947317123413
# -----------------------------------------------------------------------------
# Epoch: 4901
# error of u1: tensor(0.1477, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1622, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3895937204360962
# -----------------------------------------------------------------------------
# Epoch: 4951
# error of u1: tensor(0.1520, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1639, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3854697942733765
# -----------------------------------------------------------------------------
# Epoch: 5001
# error of u1: tensor(0.1559, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1674, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3932349681854248
# -----------------------------------------------------------------------------
# Epoch: 5051
# error of u1: tensor(0.1583, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1715, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.3935438394546509
# -----------------------------------------------------------------------------
# Epoch: 5101
# error of u1: tensor(0.1623, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1743, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4029157161712646
# -----------------------------------------------------------------------------
# Epoch: 5151
# error of u1: tensor(0.1665, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1773, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4033715724945068
# -----------------------------------------------------------------------------
# Epoch: 5201
# error of u1: tensor(0.1688, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1797, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4013776779174805
# -----------------------------------------------------------------------------
# Epoch: 5251
# error of u1: tensor(0.1723, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1813, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4073927402496338
# -----------------------------------------------------------------------------
# Epoch: 5301
# error of u1: tensor(0.1746, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1852, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4104077816009521
# -----------------------------------------------------------------------------
# Epoch: 5351
# error of u1: tensor(0.1788, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1878, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.411134123802185
# -----------------------------------------------------------------------------
# Epoch: 5401
# error of u1: tensor(0.1830, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1912, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4223320484161377
# -----------------------------------------------------------------------------
# Epoch: 5451
# error of u1: tensor(0.1866, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1941, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4111145734786987
# -----------------------------------------------------------------------------
# Epoch: 5501
# error of u1: tensor(0.1892, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1943, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4324668645858765
# -----------------------------------------------------------------------------
# Epoch: 5551
# error of u1: tensor(0.1911, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.1982, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.43497896194458
# -----------------------------------------------------------------------------
# Epoch: 5601
# error of u1: tensor(0.1959, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2033, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4331964254379272
# -----------------------------------------------------------------------------
# Epoch: 5651
# error of u1: tensor(0.1986, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2068, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4430880546569824
# -----------------------------------------------------------------------------
# Epoch: 5701
# error of u1: tensor(0.2041, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2085, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4487996101379395
# -----------------------------------------------------------------------------
# Epoch: 5751
# error of u1: tensor(0.2088, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2138, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4416507482528687
# -----------------------------------------------------------------------------
# Epoch: 5801
# error of u1: tensor(0.2137, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2154, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.458153486251831
# -----------------------------------------------------------------------------
# Epoch: 5851
# error of u1: tensor(0.2144, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2208, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4651331901550293
# -----------------------------------------------------------------------------
# Epoch: 5901
# error of u1: tensor(0.2184, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2230, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4687360525131226
# -----------------------------------------------------------------------------
# Epoch: 5951
# error of u1: tensor(0.2211, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2266, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4711755514144897
# -----------------------------------------------------------------------------
# Epoch: 6001
# error of u1: tensor(0.2260, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2285, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4700547456741333
# -----------------------------------------------------------------------------
# Epoch: 6051
# error of u1: tensor(0.2299, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2332, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.475679874420166
# -----------------------------------------------------------------------------
# Epoch: 6101
# error of u1: tensor(0.2338, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2380, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.485188364982605
# -----------------------------------------------------------------------------
# Epoch: 6151
# error of u1: tensor(0.2372, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2432, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4872112274169922
# -----------------------------------------------------------------------------
# Epoch: 6201
# error of u1: tensor(0.2421, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2429, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.4899532794952393
# -----------------------------------------------------------------------------
# Epoch: 6251
# error of u1: tensor(0.2445, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2492, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.502942442893982
# -----------------------------------------------------------------------------
# Epoch: 6301
# error of u1: tensor(0.2483, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2518, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.505511999130249
# -----------------------------------------------------------------------------
# Epoch: 6351
# error of u1: tensor(0.2500, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2569, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5076069831848145
# -----------------------------------------------------------------------------
# Epoch: 6401
# error of u1: tensor(0.2540, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2607, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5084478855133057
# -----------------------------------------------------------------------------
# Epoch: 6451
# error of u1: tensor(0.2558, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2646, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5205262899398804
# -----------------------------------------------------------------------------
# Epoch: 6501
# error of u1: tensor(0.2629, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2651, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5130589008331299
# -----------------------------------------------------------------------------
# Epoch: 6551
# error of u1: tensor(0.2631, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2691, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5090625286102295
# -----------------------------------------------------------------------------
# Epoch: 6601
# error of u1: tensor(0.2655, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2743, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.529276967048645
# -----------------------------------------------------------------------------
# Epoch: 6651
# error of u1: tensor(0.2743, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2769, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5170255899429321
# -----------------------------------------------------------------------------
# Epoch: 6701
# error of u1: tensor(0.2750, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2818, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5426479578018188
# -----------------------------------------------------------------------------
# Epoch: 6751
# error of u1: tensor(0.2777, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2859, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.548263669013977
# -----------------------------------------------------------------------------
# Epoch: 6801
# error of u1: tensor(0.2836, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2884, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.562556266784668
# -----------------------------------------------------------------------------
# Epoch: 6851
# error of u1: tensor(0.2836, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2934, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5510822534561157
# -----------------------------------------------------------------------------
# Epoch: 6901
# error of u1: tensor(0.2874, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2946, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5680172443389893
# -----------------------------------------------------------------------------
# Epoch: 6951
# error of u1: tensor(0.2897, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.2998, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.565656304359436
# -----------------------------------------------------------------------------
# Epoch: 7001
# error of u1: tensor(0.2936, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3037, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5745656490325928
# -----------------------------------------------------------------------------
# Epoch: 7051
# error of u1: tensor(0.2979, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3064, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5888164043426514
# -----------------------------------------------------------------------------
# Epoch: 7101
# error of u1: tensor(0.3017, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3123, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5896611213684082
# -----------------------------------------------------------------------------
# Epoch: 7151
# error of u1: tensor(0.3081, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3142, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.595163345336914
# -----------------------------------------------------------------------------
# Epoch: 7201
# error of u1: tensor(0.3073, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3182, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.5928449630737305
# -----------------------------------------------------------------------------
# Epoch: 7251
# error of u1: tensor(0.3113, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3226, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6086879968643188
# -----------------------------------------------------------------------------
# Epoch: 7301
# error of u1: tensor(0.3130, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(0.3244, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -1.6187483072280884
# -----------------------------------------------------------------------------
# Epoch: 7351
# ...
# Loss : -4.401979923248291
# -----------------------------------------------------------------------------
# Epoch: 27551
# error of u1: tensor(1.6144, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0470, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.253429889678955
# -----------------------------------------------------------------------------
# Epoch: 27601
# error of u1: tensor(1.6101, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0537, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.5118842124938965
# -----------------------------------------------------------------------------
# Epoch: 27651
# error of u1: tensor(1.6185, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0579, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.568779468536377
# -----------------------------------------------------------------------------
# Epoch: 27701
# error of u1: tensor(1.6244, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0549, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.521869659423828
# -----------------------------------------------------------------------------
# Epoch: 27751
# error of u1: tensor(1.6251, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0606, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.587954521179199
# -----------------------------------------------------------------------------
# Epoch: 27801
# error of u1: tensor(1.6336, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0666, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.610347270965576
# -----------------------------------------------------------------------------
# Epoch: 27851
# error of u1: tensor(1.6268, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0687, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.448538303375244
# -----------------------------------------------------------------------------
# Epoch: 27901
# error of u1: tensor(1.6357, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0783, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.597154140472412
# -----------------------------------------------------------------------------
# Epoch: 27951
# error of u1: tensor(1.6403, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0758, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.578702926635742
# -----------------------------------------------------------------------------
# Epoch: 28001
# error of u1: tensor(1.6420, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0822, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.557461738586426
# -----------------------------------------------------------------------------
# Epoch: 28051
# error of u1: tensor(1.6504, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0881, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.296263694763184
# -----------------------------------------------------------------------------
# Epoch: 28101
# error of u1: tensor(1.6439, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0921, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.632081985473633
# -----------------------------------------------------------------------------
# Epoch: 28151
# error of u1: tensor(1.6432, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0878, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.3816237449646
# -----------------------------------------------------------------------------
# Epoch: 28201
# error of u1: tensor(1.6536, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0957, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.674672603607178
# -----------------------------------------------------------------------------
# Epoch: 28251
# error of u1: tensor(1.6443, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1009, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.466567039489746
# -----------------------------------------------------------------------------
# Epoch: 28301
# error of u1: tensor(1.6649, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.0978, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.332336902618408
# -----------------------------------------------------------------------------
# Epoch: 28351
# error of u1: tensor(1.6711, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1106, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.650156497955322
# -----------------------------------------------------------------------------
# Epoch: 28401
# error of u1: tensor(1.6591, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1050, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.643977642059326
# -----------------------------------------------------------------------------
# Epoch: 28451
# error of u1: tensor(1.6752, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1187, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.614607334136963
# -----------------------------------------------------------------------------
# Epoch: 28501
# error of u1: tensor(1.6814, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1101, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.791099548339844
# -----------------------------------------------------------------------------
# Epoch: 28551
# error of u1: tensor(1.6690, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1194, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.654609203338623
# -----------------------------------------------------------------------------
# Epoch: 28601
# error of u1: tensor(1.6839, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1223, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.522988796234131
# -----------------------------------------------------------------------------
# Epoch: 28651
# error of u1: tensor(1.6869, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1225, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -3.873673915863037
# -----------------------------------------------------------------------------
# Epoch: 28701
# error of u1: tensor(1.6824, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1324, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.665836811065674
# -----------------------------------------------------------------------------
# Epoch: 28751
# error of u1: tensor(1.6985, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1294, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.63097620010376
# -----------------------------------------------------------------------------
# Epoch: 28801
# error of u1: tensor(1.6956, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1320, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.635190010070801
# -----------------------------------------------------------------------------
# Epoch: 28851
# error of u1: tensor(1.6948, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1382, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.65595817565918
# -----------------------------------------------------------------------------
# Epoch: 28901
# error of u1: tensor(1.6965, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1465, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.7093119621276855
# -----------------------------------------------------------------------------
# Epoch: 28951
# error of u1: tensor(1.6961, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1584, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.645617961883545
# -----------------------------------------------------------------------------
# Epoch: 29001
# error of u1: tensor(1.7023, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1498, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.521030426025391
# -----------------------------------------------------------------------------
# Epoch: 29051
# error of u1: tensor(1.7031, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1525, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.676634788513184
# -----------------------------------------------------------------------------
# Epoch: 29101
# error of u1: tensor(1.7069, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1468, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.350685119628906
# -----------------------------------------------------------------------------
# Epoch: 29151
# error of u1: tensor(1.7116, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1490, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.802023410797119
# -----------------------------------------------------------------------------
# Epoch: 29201
# error of u1: tensor(1.7169, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1534, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.81256628036499
# -----------------------------------------------------------------------------
# Epoch: 29251
# error of u1: tensor(1.7183, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1514, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.662848949432373
# -----------------------------------------------------------------------------
# Epoch: 29301
# error of u1: tensor(1.7230, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1616, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.65769624710083
# -----------------------------------------------------------------------------
# Epoch: 29351
# error of u1: tensor(1.7246, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1597, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.475383758544922
# -----------------------------------------------------------------------------
# Epoch: 29401
# error of u1: tensor(1.7288, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1629, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.441289901733398
# -----------------------------------------------------------------------------
# Epoch: 29451
# error of u1: tensor(1.7264, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1770, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.833667755126953
# -----------------------------------------------------------------------------
# Epoch: 29501
# error of u1: tensor(1.7302, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1749, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.815611362457275
# -----------------------------------------------------------------------------
# Epoch: 29551
# error of u1: tensor(1.7398, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1755, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.861232757568359
# -----------------------------------------------------------------------------
# Epoch: 29601
# error of u1: tensor(1.7411, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1829, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.87939453125
# -----------------------------------------------------------------------------
# Epoch: 29651
# error of u1: tensor(1.7474, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1812, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.78005838394165
# -----------------------------------------------------------------------------
# Epoch: 29701
# error of u1: tensor(1.7410, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1822, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.899337291717529
# -----------------------------------------------------------------------------
# Epoch: 29751
# error of u1: tensor(1.7410, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1889, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.94688081741333
# -----------------------------------------------------------------------------
# Epoch: 29801
# error of u1: tensor(1.7520, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1918, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.72886848449707
# -----------------------------------------------------------------------------
# Epoch: 29851
# error of u1: tensor(1.7518, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1955, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.622809886932373
# -----------------------------------------------------------------------------
# Epoch: 29901
# error of u1: tensor(1.7566, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1953, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.610020160675049
# -----------------------------------------------------------------------------
# Epoch: 29951
# error of u1: tensor(1.7525, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of u2: tensor(2.1966, device='cuda:0', grad_fn=<SqrtBackward0>)
# error of P: tensor(1.0000, device='cuda:0', grad_fn=<SqrtBackward0>)
# Loss : -4.17841911315918

# %%
import matplotlib.pyplot as plt

plt.plot(error_drm_list1, label='Error of u1')
plt.plot(error_drm_list2, label='Error of u2')
plt.plot(error_drm_list3, label='Error of P')

#plt.title('DRM for p-Stokes Equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Error')
plt.yscale('log')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(loss_list3, label='DRM Loss')

#plt.title('DRM for p-Stokes Equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Loss')
#plt.yscale('log')

plt.legend()

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import torch
from torch.autograd import Variable

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
r=1

# 데이터 생성
x_collocation = []
y_collocation = []
p_collocation = []

theta = np.linspace(0, 2*np.pi, 120)
x = np.cos(theta)
y = np.sin(theta)

X, Y = np.meshgrid(x, y)

pt_x = Variable(torch.from_numpy(X).float(), requires_grad=False).to(device)
pt_y = Variable(torch.from_numpy(Y).float(), requires_grad=False).to(device)

pt_x = pt_x.reshape(-1,1)
pt_y = pt_y.reshape(-1,1)
pt_p = 2.5*torch.ones_like(pt_x)   #2 < p < 4

# 신경망 예측
Predict1 = net_drm_1(pt_x, pt_y, pt_p)
Predict2 = net_drm_2(pt_x, pt_y, pt_p)
Predict3 = net_drm_P(pt_x, pt_y, pt_p)
Truesol1 = k*pt_y * (r**2 - pt_x**2 - pt_y**2)
Truesol2 = -k*pt_x * (r**2 - pt_x**2 - pt_y**2)
Truesol3 = 3*(pt_x + pt_y)

Predict1 = Predict1.data.cpu().numpy()
Predict2 = Predict2.data.cpu().numpy()
Predict3 = Predict3.data.cpu().numpy()
Truesol1 = Truesol1.data.cpu().numpy()
Truesol2 = Truesol2.data.cpu().numpy()
Truesol3 = Truesol3.data.cpu().numpy()

PR_u1 = Predict1.reshape(X.shape)
PR_u2 = Predict2.reshape(X.shape)
PR_P = Predict3.reshape(X.shape)
Truesol1 = Truesol1.reshape(X.shape)
Truesol2 = Truesol2.reshape(X.shape)
Truesol3 = Truesol3.reshape(X.shape)

# 마스크 생성

mask = (X**2 + Y**2 > r**2)
PR_u1[mask] = 0
PR_u2[mask] = 0
PR_P[mask] = 0
Truesol1[mask] = 0
Truesol2[mask] = 0
Truesol3[mask] = 0

# 3D 표면 플롯
surf = ax.plot_surface(X, Y, PR_u2, cmap=cm.coolwarm, linewidth=0, antialiased=False)
#surf = ax.plot_surface(X, Y, Truesol3, cmap=cm.coolwarm, linewidth=0, antialiased=False)
#surf = ax.plot_surface(X, Y, (Truesol3 - PR_P), cmap=cm.coolwarm, linewidth=0, antialiased=False)

# 색상 바 추가
fig.colorbar(surf, shrink=0.5, aspect=4)
#plt.title('Solution - Prediction for p=3 (P)')

# z축 범위 및 눈금 설정
#ax.set_zlim(0, 1)  # z축의 값 범위를 설정
#ax.set_zticks(np.arange(0, 1, 0.1))  # z축 눈금을 -0.15부터 0.15까지 0.05 간격으로 설정

plt.show()

# %% [markdown]
# # Plots

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import torch
from torch.autograd import Variable

# Set a fixed w value
p = 3.5

y_np = np.linspace(-1, 1, 500)
p_np = p*np.ones_like(y_np)
#x_np = np.zeros_like(y_np)
x_np = np.zeros_like(y_np)

x = Variable(torch.from_numpy(x_np).float().unsqueeze(1), requires_grad=True).to(device)
y = Variable(torch.from_numpy(y_np).float().unsqueeze(1), requires_grad=True).to(device)
p = Variable(torch.from_numpy(p_np).float().unsqueeze(1), requires_grad=True).to(device)

# f(x, y) 계산
z_PINN = net_pinn_1(x, y, p).cpu().detach().numpy()
z_PINN_df = (k*y*(1 - x**2 - y**2) - net_pinn_1(x, y, p)).cpu().detach().numpy()
z_DRM = net_drm_1(x, y, p).cpu().detach().numpy()
z_DRM_df = (k*y*(1 - x**2 - y**2) - net_drm_1(x, y, p)).cpu().detach().numpy()
z_Mix = net_2d_1(x, y, p).cpu().detach().numpy()
z_Mix_df = (k*y*(1 - x**2 - y**2) - net_2d_1(x, y, p)).cpu().detach().numpy()
z_Sol = (k*y*(1 - x**2 - y**2)).cpu().detach().numpy()

# 2D 그래프로 시각화
plt.figure(figsize=(8, 6))
#plt.rcParams["text.usetex"] = False
plt.plot(y_np, z_PINN, label=r"$u_\mathrm{PINN}(\mathcal{p}, \cdot)$")
plt.plot(y_np, z_DRM, label=r"$u_\mathrm{DRM}(\mathcal{p}, \cdot)$")
plt.plot(y_np, z_Mix, label=r"$u_\mathrm{Hyb}(\mathcal{p}, \cdot)$")
plt.plot(y_np, z_Sol, linestyle = '--', label=r"$\mathcal{u}^*(\mathcal{p}, \cdot)$")

#plt.plot(y_np, z_PINN_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{PINN}(\mathcal{p}, \cdot)$")
#plt.plot(y_np, z_DRM_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{DRM}(\mathcal{p}, \cdot)$")
#plt.plot(y_np, z_Mix_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{Hyb}(\mathcal{p}, \cdot)$")

#plt.title("w = 6")
#plt.xlabel("y")
#plt.ylabel("f(x, y)")
#plt.ylim(0,0.12)
plt.legend()
#plt.grid()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import torch
from torch.autograd import Variable

# Set a fixed w value
p = 3.5

x_np = np.linspace(-1, 1, 500)
p_np = p*np.ones_like(x_np)
#x_np = np.zeros_like(y_np)
y_np = np.zeros_like(x_np)

x = Variable(torch.from_numpy(x_np).float().unsqueeze(1), requires_grad=True).to(device)
y = Variable(torch.from_numpy(y_np).float().unsqueeze(1), requires_grad=True).to(device)
p = Variable(torch.from_numpy(p_np).float().unsqueeze(1), requires_grad=True).to(device)

# f(x, y) 계산
z_PINN = net_pinn_2(x, y, p).cpu().detach().numpy()
z_PINN_df = (-k*x*(1 - x**2 - y**2) - net_pinn_2(x, y, p)).cpu().detach().numpy()
z_DRM = net_drm_2(x, y, p).cpu().detach().numpy()
z_DRM_df = (-k*x*(1 - x**2 - y**2) - net_drm_2(x, y, p)).cpu().detach().numpy()
z_Mix = net_2d_2(x, y, p).cpu().detach().numpy()
z_Mix_df = (-k*x*(1 - x**2 - y**2) - net_2d_2(x, y, p)).cpu().detach().numpy()
z_Sol = (-k*x*(1 - x**2 - y**2)).cpu().detach().numpy()

# 2D 그래프로 시각화
plt.figure(figsize=(8, 6))
#plt.rcParams["text.usetex"] = False
#plt.plot(x_np, z_PINN, label=r"$u_\mathrm{PINN}(\mathcal{p}, \cdot)$")
#plt.plot(x_np, z_DRM, label=r"$u_\mathrm{DRM}(\mathcal{p}, \cdot)$")
#plt.plot(x_np, z_Mix, label=r"$u_\mathrm{Hyb}(\mathcal{p}, \cdot)$")
#plt.plot(x_np, z_Sol, linestyle = '--', label=r"$\mathcal{u}^*(\mathcal{p}, \cdot)$")

plt.plot(x_np, z_PINN_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{PINN}(\mathcal{p}, \cdot)$")
plt.plot(x_np, z_DRM_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{DRM}(\mathcal{p}, \cdot)$")
plt.plot(x_np, z_Mix_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{Hyb}(\mathcal{p}, \cdot)$")

#plt.title("w = 6")
#plt.xlabel("y")
#plt.ylabel("f(x, y)")
#plt.ylim(0,0.12)
plt.legend()
plt.grid()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import torch
from torch.autograd import Variable

# Set a fixed w value
p = 3.5

y_np = np.linspace(-1, 1, 500)
p_np = p*np.ones_like(y_np)
#x_np = np.zeros_like(y_np)
x_np = np.zeros_like(y_np)

x = Variable(torch.from_numpy(x_np).float().unsqueeze(1), requires_grad=True).to(device)
y = Variable(torch.from_numpy(y_np).float().unsqueeze(1), requires_grad=True).to(device)
p = Variable(torch.from_numpy(p_np).float().unsqueeze(1), requires_grad=True).to(device)

# f(x, y) 계산
z_PINN = net_pinn_P(x, y, p).cpu().detach().numpy()
z_PINN_df = (3*(x + y) - net_pinn_P(x, y, p)).cpu().detach().numpy()
z_DRM = net_drm_P(x, y, p).cpu().detach().numpy()
z_DRM_df = (3*(x + y) - net_drm_P(x, y, p)).cpu().detach().numpy()
z_Mix = net_2d_P(x, y, p).cpu().detach().numpy()
z_Mix_df = (3*(x + y) - net_2d_P(x, y, p)).cpu().detach().numpy()
z_Sol = (3*(x + y)).cpu().detach().numpy()

# 2D 그래프로 시각화
plt.figure(figsize=(8, 6))
#plt.rcParams["text.usetex"] = False
#plt.plot(y_np, z_PINN, label=r"$u_\mathrm{PINN}(\mathcal{p}, \cdot)$")
#plt.plot(y_np, z_DRM, label=r"$u_\mathrm{DRM}(\mathcal{p}, \cdot)$")
#plt.plot(y_np, z_Mix, label=r"$u_\mathrm{Hyb}(\mathcal{p}, \cdot)$")
#plt.plot(y_np, z_Sol, linestyle = '--', label=r"$\mathcal{u}^*(\mathcal{p}, \cdot)$")

plt.plot(y_np, z_PINN_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{PINN}(\mathcal{p}, \cdot)$")
plt.plot(y_np, z_DRM_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{DRM}(\mathcal{p}, \cdot)$")
plt.plot(y_np, z_Mix_df, label=r"$u^{*}(\mathcal{p}, \cdot) - u_\mathrm{Hyb}(\mathcal{p}, \cdot)$")

#plt.title("w = 6")
#plt.xlabel("y")
#plt.ylabel("f(x, y)")
#plt.ylim(0,0.12)
plt.legend()
plt.grid()
plt.show()

# %%
#Hybrid_x=0_u1

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
y_vals = np.linspace(-1, 1, 100)
p_vals = np.linspace(2, 4, 100)

# 2D 그리드 생성 (y,w)
y_grid, p_grid = np.meshgrid(y_vals, p_vals)

# x=0 고정
x_grid = np.zeros_like(y_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
#sol_plot = net_2d_1(pt_x_plot, pt_y_plot, pt_p_plot)
#sol_plot = k*pt_y_plot*(1 - pt_x_plot**2 - pt_y_plot**2) - net_2d_1(pt_x_plot, pt_y_plot, pt_p_plot)
sol_plot = k*pt_y_plot*(1 - pt_x_plot**2 - pt_y_plot**2)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(y_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
#ax.set_zlim(-0.01,0.01)
ax.view_init(elev=30, azim=280)
ax.set_box_aspect([1, 2, 1])

plt.show()

# %%
#PINN_x=0_u1

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
y_vals = np.linspace(-1, 1, 100)      # 원래 코드에서 y 범위 [-1,1]
p_vals = np.linspace(2, 4, 100)     # p 범위 [0.1, 6]

# 2D 그리드 생성 (y,w)
y_grid, p_grid = np.meshgrid(y_vals, p_vals)

# x=0 고정
x_grid = np.zeros_like(y_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
sol_plot = net_pinn_1(pt_x_plot, pt_y_plot, pt_p_plot)
#sol_plot = k*pt_y_plot*(1 - pt_x_plot**2 - pt_y_plot**2) - net_pinn_1(pt_x_plot, pt_y_plot, pt_p_plot)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(y_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
ax.set_box_aspect([1, 2, 1])
ax.view_init(elev=30, azim=280)
#ax.set_zlim(-0.01,0.01)

plt.show()

# %%
#DRM_x=0_u1

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
y_vals = np.linspace(-1, 1, 100)      # 원래 코드에서 y 범위 [-1,1]
p_vals = np.linspace(2, 4, 100)     # p 범위 [0.1, 6]

# 2D 그리드 생성 (y,w)
y_grid, p_grid = np.meshgrid(y_vals, p_vals)

# x=0 고정
x_grid = np.zeros_like(y_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
sol_plot = net_drm_1(pt_x_plot, pt_y_plot, pt_p_plot)
#sol_plot = k*pt_y_plot*(1 - pt_x_plot**2 - pt_y_plot**2) - net_drm_1(pt_x_plot, pt_y_plot, pt_p_plot)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(y_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
ax.set_box_aspect([1, 2, 1])
ax.view_init(elev=30, azim=280)
#ax.set_zlim(-0.01,0.01)

plt.show()

# %%
#Hybrid_y=0_u2

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
x_vals = np.linspace(-1, 1, 100)      # 원래 코드에서 y 범위 [-1,1]
p_vals = np.linspace(2, 4, 100)     # p 범위 [0.1, 6]

# 2D 그리드 생성 (y,w)
x_grid, p_grid = np.meshgrid(x_vals, p_vals)

# x=0 고정
y_grid = np.zeros_like(x_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
#sol_plot = net_2d_2(pt_x_plot, pt_y_plot, pt_p_plot)
#sol_plot = k*(-pt_x_plot)*(1 - pt_x_plot**2 - pt_y_plot**2) - net_2d_2(pt_x_plot, pt_y_plot, pt_p_plot)
sol_plot = k*(-pt_x_plot)*(1 - pt_x_plot**2 - pt_y_plot**2)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(x_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
ax.set_box_aspect([1, 2, 1])
ax.view_init(elev=30, azim=280)
#ax.set_zlim(-0.01,0.01)

plt.show()

# %%
#PINN_y=0_u2

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
x_vals = np.linspace(-1, 1, 100)      # 원래 코드에서 y 범위 [-1,1]
p_vals = np.linspace(2, 4, 100)     # p 범위 [0.1, 6]

# 2D 그리드 생성 (y,w)
x_grid, p_grid = np.meshgrid(x_vals, p_vals)

# x=0 고정
y_grid = np.zeros_like(x_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
sol_plot = net_pinn_2(pt_x_plot, pt_y_plot, pt_p_plot)
#sol_plot = k*(-pt_x_plot)*(1 - pt_x_plot**2 - pt_y_plot**2) - net_pinn_2(pt_x_plot, pt_y_plot, pt_p_plot)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(x_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
ax.set_box_aspect([1, 2, 1])
ax.view_init(elev=30, azim=280)
#ax.set_zlim(-0.01,0.01)

plt.show()

# %%
#DRM_y=0_u2

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
x_vals = np.linspace(-1, 1, 100)      # 원래 코드에서 y 범위 [-1,1]
p_vals = np.linspace(2, 4, 100)     # p 범위 [0.1, 6]

# 2D 그리드 생성 (y,w)
x_grid, p_grid = np.meshgrid(x_vals, p_vals)

# x=0 고정
y_grid = np.zeros_like(x_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
sol_plot = net_drm_2(pt_x_plot, pt_y_plot, pt_p_plot)
#sol_plot = k*(-pt_x_plot)*(1 - pt_x_plot**2 - pt_y_plot**2) - net_drm_2(pt_x_plot, pt_y_plot, pt_p_plot)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(x_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
ax.set_box_aspect([1, 2, 1])
ax.view_init(elev=30, azim=280)
#ax.set_zlim(-0.1,0.1)

plt.show()

# %%
#Hybrid_x=0_P

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
y_vals = np.linspace(-1, 1, 100)      # 원래 코드에서 y 범위 [-1,1]
p_vals = np.linspace(2, 4, 100)     # p 범위 [0.1, 6]

# 2D 그리드 생성 (y,w)
y_grid, p_grid = np.meshgrid(y_vals, p_vals)

# x=0 고정
x_grid = np.zeros_like(y_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
#sol_plot = net_2d_P(pt_x_plot, pt_y_plot, pt_p_plot)
#sol_plot = 3*(pt_x_plot + pt_y_plot) - net_2d_P(pt_x_plot, pt_y_plot, pt_p_plot)
sol_plot = 3*(pt_x_plot + pt_y_plot)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(y_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
ax.set_box_aspect([1, 2, 1])
ax.view_init(elev=30, azim=280)
#ax.set_zlim(-0.1,0.1)

plt.show()

# %%
#PINN_x=0_P

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
y_vals = np.linspace(-1, 1, 100)      # 원래 코드에서 y 범위 [-1,1]
p_vals = np.linspace(2, 4, 100)     # p 범위 [0.1, 6]

# 2D 그리드 생성 (y,w)
y_grid, p_grid = np.meshgrid(y_vals, p_vals)

# x=0 고정
x_grid = np.zeros_like(y_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
sol_plot = net_pinn_P(pt_x_plot, pt_y_plot, pt_p_plot)
#sol_plot = 3*(pt_x_plot + pt_y_plot) - net_pinn_P(pt_x_plot, pt_y_plot, pt_p_plot)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(y_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
ax.view_init(elev=30, azim=280)
ax.set_box_aspect([1, 2, 1])

plt.show()

# %%
#DRM_x=0_P

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# y와 w의 범위 설정
y_vals = np.linspace(-1, 1, 100)      # 원래 코드에서 y 범위 [-1,1]
p_vals = np.linspace(2, 4, 100)     # p 범위 [0.1, 6]

# 2D 그리드 생성 (y,w)
y_grid, p_grid = np.meshgrid(y_vals, p_vals)

# x=0 고정
x_grid = np.zeros_like(y_grid)

# torch tensor 변환
pt_x_plot = torch.tensor(x_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_y_plot = torch.tensor(y_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)
pt_p_plot = torch.tensor(p_grid.ravel(), dtype=torch.float32).to(device).view(-1, 1)

# u(x=0,y,w) 계산
#sol_plot = net_drm_P(pt_x_plot, pt_y_plot, pt_p_plot)
sol_plot = 3*(pt_x_plot + pt_y_plot) - net_drm_P(pt_x_plot, pt_y_plot, pt_p_plot)

# 다시 2D grid 형태로 변환
sol_plot_reshaped = sol_plot.detach().cpu().numpy().reshape(y_grid.shape)

# 그래프 그리기
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(y_grid, p_grid, sol_plot_reshaped, cmap='viridis')

# 색상바 추가
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
#cbar.set_label("u(0, y, p)")

# 레이블 설정
#ax.set_xlabel("y")
#ax.set_ylabel("p")
#ax.set_zlabel("u")
#ax.set_title("3D Plot of u(0, y, p)")
ax.view_init(elev=30, azim=280)
ax.set_box_aspect([1, 2, 1])
#ax.set_zlim(-0.1,0.1)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(error_drm_list1, label='DRM Error')
plt.plot(error_pinn_list1, label='PINN Error')
plt.plot(error_list1, label='Hybrid Error')

#plt.title('DRM for parametric stokes equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Error')
#plt.yscale('log')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(error_drm_list2, label='DRM Error')
plt.plot(error_pinn_list2, label='PINN Error')
plt.plot(error_list2, label='Hybrid Error')

#plt.title('DRM for parametric stokes equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Error')
#plt.yscale('log')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(error_drm_list3, label='DRM Error')
plt.plot(error_pinn_list3, label='PINN Error')
plt.plot(error_list3, label='Hybrid Error')

#plt.title('DRM for parametric stokes equation')
plt.xlabel('Epochs (per 50 epochs)')
plt.ylabel('Error')
#plt.yscale('log')

plt.legend()

plt.show()
